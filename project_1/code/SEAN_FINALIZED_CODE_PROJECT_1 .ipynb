# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** For us to improve the participation rates of SAT scores across all states, we need to see if there are any states with significant increase in participation rates over the years, and find out what education policies related to ACT/SAT have changed over these years.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:**
# ## Problem statement:
# - The SAT, which is administered by the College board, is a standardized test that is used for college admissions in the U.S. As the board of directors on the Educational Testing Services under the College Board, we assert that participation in SAT test may likely translate to fair evaluations on students' readiness for college/career, increase their chances of gaining admission to good schools and subsequent upward social mobility in the long-term. We are especially concerned with low SAT participation rates amongst students from poorer socio-economic counties in California, U.S, and would like to propose best practices to improve SAT participation amongst students from low socio-economic counties.
#
#
# outline:
# 1. Show graphs to show the participation rates of US.
# 2. Critique that this participate rate does not show specifically the make up of poor vs rich participation.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# #importing CSV files to be used
#
# - sat2017 = pd.read_csv('data/sat_2017.csv') #participation rate and scores in SAT in2017 by US states
# - sat2018 = pd.read_csv('data/sat_2018.csv') #participation rate and scores in SAT in2018 by US states
# - sat2019 = pd.read_csv('data/sat_2019.csv') #participation rate and scores in SAT in2019 by US states
# - sat2019cali = pd.read_csv('data/sat_2019_ca.csv') #participation rate and scores of counties for SAT in 2019 in the various counties in California, US.
# - hhincome2019 = pd.read_csv('data/Median_Household_Income_by_County.csv') #Median Household income by County for 2019

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
import math

# %%
# Code:

def mean_calculation(num):
    return sum(num) / len(num)

mean_calculation([1,2,31])
# Out:
# 11.333333333333334

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def variance(data):
    n = len(data)          # Number of observations
    mean = sum(data) / n # Mean of the data
    deviations = [(x - mean) ** 2 for x in data] # Square deviations
    variance = sum(deviations) / n
    return variance

def stdev(data):
    var = variance(data)
    std_dev = math.sqrt(var)
    return std_dev

stdev([4,4,4,3,4,4])
# Out:
# 0.3726779962499649

# %% [markdown]
# 3. Data cleaning function:
#
# Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def clean_data(n):
    if n != 'NaN':
        return (float(n.rstrip("%")))/100

# %%
clean_data('23.5%')
# Out:
# 0.235

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %%
#*All libraries used should be added here*
import scipy.stats as stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#importing CSV files to be used 

sat2017 = pd.read_csv('data/sat_2017.csv') #participation rate and scores in SAT in2017
sat2018 = pd.read_csv('data/sat_2018.csv') #participation rate and scores in SAT in2018
sat2019 = pd.read_csv('data/sat_2019.csv') #participation rate and scores in SAT in2019
sat2019cali = pd.read_csv('data/sat_2019_ca.csv') #participation rate and scores of counties for SAT in2019 in the various counties in California, US.

# %%
print(type(sat2019))
print(sat2019.shape)
print(sat2019.info())
sat2019.head()
#on first look, column headings could be better labeled
#participation rate is an object. We should change it to float/int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (53, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB
# None
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
print(type(sat2018))
print(sat2018.shape)
print(sat2018.info())
sat2018.head()
#similar first look, column headings should be appropriately labeled
#participation rate is an object. We should change it to float/int
#Based on shape, it is 2 less rows then sat2019
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (51, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# ...

# %%
print(type(sat2017))
print(sat2017.shape)
print(sat2017.info())
sat2017.head()
#similar first look, column headings should be appropriately labeled
#participation rate is an object. We should change it to float/int
#Based on shape, it is similar to 2018, but two rows less than sat2019
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (51, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# ...

# %%
lis = []
unique2018 = sat2018['State'].unique()

for each_value in sat2019['State']:
    if each_value in unique2018:
        continue
    else:
        lis.append(each_value)
        
    print(lis)

#This shows the two counties that are newly added to SAT2019!
# Out:
# ['Puerto Rico']
# ['Puerto Rico', 'Virgin Islands']

# %%
#Change the columns names to lowercase, rename all columns, removing all symbols, and change type to float.

sat2017.columns = sat2017.columns.str.lower()

# %%
sat2017.rename(columns = {'participation': 'participation_rate', "evidence-based reading and writing": "ebrw"}, inplace=True)

# %%
sat2017['participation_rate'] = sat2017['participation_rate'].apply(clean_data) #remember apply the clean data from part 1

# %%
sat2017.info() # YES! Successfully changed column name and dtype for sat2017
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               51 non-null     object
#  1   participation_rate  51 non-null     float64
#  2   ebrw                51 non-null     int64
#  3   math                51 non-null     int64
#  4   total               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
#Change the columns names to lowercase, rename all columns, removing all symbols, and change type to float.

sat2018.columns = sat2018.columns.str.lower()

# %%
sat2018.rename(columns = {'participation': 'participation_rate', "evidence-based reading and writing": "ebrw"}, inplace=True)

# %%
sat2018['participation_rate'] = sat2018['participation_rate'].apply(clean_data) #remember apply the clean data from part 1

# %%
sat2018.info()# YES! Successfully changed column name and dtype for sat2018
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               51 non-null     object
#  1   participation_rate  51 non-null     float64
#  2   ebrw                51 non-null     int64
#  3   math                51 non-null     int64
#  4   total               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
#for 2019, the '-' values in Puerto Rico and Virgin Islands may require changing to NaN value. 
#Then I will proceed to change the columns names to lowercase, rename all columns, removing all symbols, and change type to float.

sat2019['Participation Rate'].replace('—', np.nan, inplace=True)

# %%
sat2019.columns = sat2019.columns.str.lower()

# %%
sat2019.rename(columns = {'participation rate': 'participation_rate'}, inplace=True)

# %%
sat2019['participation_rate'].replace(np.nan, '0%', inplace=True)

# %%
sat2019['participation_rate'] = sat2019['participation_rate'].apply(clean_data) 
#remember apply the clean data from part 1, but it wouldnt work here because of the NaN values

# %%
sat2019 # Yay it works!
# Out:
#                    state  participation_rate  ebrw  math  total
# 0                Alabama                0.07   583   560   1143
# 1                 Alaska                0.41   556   541   1097
# 2                Arizona                0.31   569   565   1134
# 3               Arkansas                0.06   582   559   1141
# 4             California                0.63   534   531   1065
# 5               Colorado                1.00   518   506   1024
# 6            Connecticut                1.00   529   516   1046
# 7               Delaware                1.00   499   486    985
# 8   District of Columbia                0.94   495   480    975
# 9                Florida                1.00   516   483    999
# 10               Georgia                0.71   538   519   1058
# 11                Hawaii                0.54   550   550   1100
# 12                 Idaho                1.00   505   488    993
# 13              Illinois                1.00   509   504   1013
# ...

# %%
sat2019.info()# YES! Successfully changed column name and dtype for sat2018
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   state               53 non-null     object
#  1   participation_rate  53 non-null     float64
#  2   ebrw                53 non-null     int64
#  3   math                53 non-null     int64
#  4   total               53 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.2+ KB

# %%
# Remember that the sat2019 shape is different from 2017 and 2018.
print(f'sat2017_dataframe shape: {sat2017.shape}')
print(f'sat2018_dataframe shape: {sat2018.shape}')
print(f'sat2019_dataframe shape: {sat2019.shape}')
# Out:
# sat2017_dataframe shape: (51, 5)
# sat2018_dataframe shape: (51, 5)
# sat2019_dataframe shape: (53, 5)

# %%
sat2017_18_19 = pd.merge(pd.merge(sat2017,sat2018,on='state'), sat2019,on='state')

# %%
sat2017_18_19
#Puerto Rico and Virgin Islands to be excluded since participation rates there are NaN/0%
# Out:
#                    state  participation_rate_x  ebrw_x  math_x  total_x  \
# 0                Alabama                  0.05     593     572     1165
# 1                 Alaska                  0.38     547     533     1080
# 2                Arizona                  0.30     563     553     1116
# 3               Arkansas                  0.03     614     594     1208
# 4             California                  0.53     531     524     1055
# 5               Colorado                  0.11     606     595     1201
# 6            Connecticut                  1.00     530     512     1041
# 7               Delaware                  1.00     503     492      996
# 8   District of Columbia                  1.00     482     468      950
# 9                Florida                  0.83     520     497     1017
# 10               Georgia                  0.61     535     515     1050
# 11                Hawaii                  0.55     544     541     1085
# ...

# %%
sat2017_18_19.rename(columns = {'participation_rate_x': 'participationrate_2017', 'ebrw_x': 'ebrw_17', 'math_x': 'math_17','total_x': 'total_17', 
                                'participation_rate_y': 'participationrate_2018', 'ebrw_y': 'ebrw_18', 'math_y' : 'math_18', 'total_y': 'total_18',
                                'participation_rate' : 'participationrate_2019', 'ebrw':'ebrw_19', 'math': 'math_19', 'total': 'total_19'
                               }, inplace=True )

# %%
sat2017_18_19
# Out:
#                    state  participationrate_2017  ebrw_17  math_17  total_17  \
# 0                Alabama                    0.05      593      572      1165
# 1                 Alaska                    0.38      547      533      1080
# 2                Arizona                    0.30      563      553      1116
# 3               Arkansas                    0.03      614      594      1208
# 4             California                    0.53      531      524      1055
# 5               Colorado                    0.11      606      595      1201
# 6            Connecticut                    1.00      530      512      1041
# 7               Delaware                    1.00      503      492       996
# 8   District of Columbia                    1.00      482      468       950
# 9                Florida                    0.83      520      497      1017
# 10               Georgia                    0.61      535      515      1050
# ...

# %%
#now I want to compare the mean participation rate in 2017 and 2018 and 2019
print(round(sat2017_18_19['participationrate_2017'].mean(),2))
print(round(sat2017_18_19['participationrate_2018'].mean(),2))
print(round(sat2017_18_19['participationrate_2019'].mean(),2))


plt.figure(figsize=(6, 4)) # recap: shift+tab for parameter details (width, height)

plt.bar(x=['2017', '2018', '2019'], # We have to specify our X labels/location.
        height=[sat2017_18_19['participationrate_2017'].mean(), sat2017_18_19['participationrate_2018'].mean(), sat2017_18_19['participationrate_2019'].mean()], color=['yellow', 'mediumseagreen', 'pink' ], edgecolor='cyan') # We have to specify the Y height.

# Add a title and show the plot.
plt.title(' Fig 1: 2017 vs. 2018 vs. 2019 Participation rates', {'fontsize': 15});
plt.xlabel('Participation rate based on year')
plt.ylabel('Participation rate in %');
# Out:
# 0.4
# 0.46
# 0.49

# %%
sat2017_18_19.describe()
#We got some basic descriptive statistics
#we can observe that the mean participation rate has been increasing from 2017 to 2019.
# Out:
#        participationrate_2017     ebrw_17     math_17     total_17  \
# count               51.000000   51.000000   51.000000    51.000000
# mean                 0.398039  569.117647  547.627451  1126.098039
# std                  0.352766   45.666901   84.909119    92.494812
# min                  0.020000  482.000000   52.000000   950.000000
# 25%                  0.040000  533.500000  522.000000  1055.500000
# 50%                  0.380000  559.000000  548.000000  1107.000000
# 75%                  0.660000  613.000000  599.000000  1212.000000
# max                  1.000000  644.000000  651.000000  1295.000000
#
#        participationrate_2018     ebrw_18     math_18     total_18  \
# count               51.000000   51.000000   51.000000    51.000000
# mean                 0.457451  563.686275  556.235294  1120.019608
# std                  0.373143   47.502627   47.772623    94.155083
# min                  0.020000  480.000000  480.000000   977.000000
# ...

# %%
#Let's zoom into 2019's participation rate.
sat2017_18_19['participationrate_2019'].mean()
# Out:
# 0.49058823529411755

# %%
#The largest state is California, and comprises 1.95 million students enrolled in public high schools in California, the highest figure in the United States  (https://www.statista.com/statistics/183497/population-in-the-federal-states-of-the-us/)
# Lets take a look at whether California is in the top 15 participation rate in 2019.

# %%
sat2017_18_19.sort_values(by ='participationrate_2019', ascending = False).head(15)
#California is not even in the top 15 states with highest participation rates in SAT.
# Out:
#                    state  participationrate_2017  ebrw_17  math_17  total_17  \
# 39          Rhode Island                    0.71      539      524      1062
# 13              Illinois                    0.09      559      556      1115
# 22              Michigan                    1.00      509      495      1005
# 5               Colorado                    0.11      606      595      1201
# 6            Connecticut                    1.00      530      512      1041
# 7               Delaware                    1.00      503      492       996
# 9                Florida                    0.83      520      497      1017
# 12                 Idaho                    0.93      513      493      1005
# 19                 Maine                    0.95      513      499      1012
# 48         West Virginia                    0.14      558      528      1086
# 29         New Hampshire                    0.96      532      520      1052
# ...

# %%
#let's compare the largest state, California, with the mean participation rates in 2019

sat2017_18_19[sat2017_18_19['state'] == 'California'][['state', 'participationrate_2017', 'participationrate_2018', 'participationrate_2019']]
# Out:
#         state  participationrate_2017  participationrate_2018  \
# 4  California                    0.53                     0.6
#
#    participationrate_2019
# 4                    0.63

# %% [markdown]
# ## Analysis
#
# - Based on the descriptive statistics above, SAT participation rates continue to rise from years 2017 through to 2019 (from 38% in 2017, to 45% in 2018 and 49% in 2019) has been shown.
# - Preliminary data analysis above show that California - being the largest U.S. state - continues to show consistently low SAT participation rates as compared to other states. The data shows California is not even in the top 15 states with the most SAT participation. This is even more surprising to note given that California, being ranked the largest US state, comprise of 1.95 million students enrolled in public high schools in California, the highest figure in the United States. (https://www.statista.com/statistics/1036120/public-high-school-enrollment-state-us/).
#
# - We are curious to examine the state of California to understand participation rates and see what factors contribute to lower SAT participation rates. We then aim to propose best practices to improve SAT participation rates based on these contributing factors.
#
# - Let's go!!

# %%
#Finally, let's save the new merged file as csv 
sat2017_18_19.to_csv('sat2017_18_19.csv')

# %%
## This is the 2019 dataset on SAT for the state of California
## Observe that there are some * values in some rows

print(sat2019cali.shape)
print(sat2019cali.info())
sat2019cali.head()
# Out:
# (2580, 26)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %%
#These is the range and unique values of counties 

print(sat2019cali['CName'].nunique())
sat2019cali['CName'].unique()
# Out:
# 59
# array(['Colusa', 'Los Angeles', 'Orange', 'Riverside', 'Imperial',
#        'San Bernardino', 'Kern', 'San Diego', 'Fresno', 'San Joaquin',
#        'Nevada', 'San Mateo', 'Contra Costa', 'Humboldt', 'Placer',
#        'Alameda', 'Glenn', 'Sacramento', 'San Francisco', 'Marin',
#        'Santa Barbara', 'El Dorado', 'Merced', 'Siskiyou', 'Madera',
#        'Sonoma', 'Trinity', 'Tulare', 'Santa Clara', 'Solano',
#        'San Luis Obispo', 'Stanislaus', 'Ventura', 'Santa Cruz', 'Lassen',
#        'Calaveras', 'Monterey', 'Modoc', 'Yolo', 'Tehama', 'Butte',
#        'Tuolumne', 'Sutter', 'Mendocino', 'Lake', 'Amador', 'Kings',
#        'Napa', 'Sierra', 'Shasta', 'Del Norte', 'San Benito', 'Inyo',
#        'Yuba', 'Plumas', 'Mono', 'Mariposa', 'Alpine',
#        'State of California', nan], dtype=object)

# %%
#first change column name to str.lower first!!!
sat2019cali.columns = sat2019cali.columns.str.lower()

# %%
#filter by county!!
sat2019cali = sat2019cali[sat2019cali.rtype=='C']

# %%
print(sat2019cali.shape)
sat2019cali
# Out:
# (58, 26)
#                cds  ccode     cdcode  scode rtype sname dname  \
# 1981  9.000000e+12    9.0   900000.0    0.0     C   NaN   NaN
# 1982  1.900000e+13   19.0  1900000.0    0.0     C   NaN   NaN
# 1983  2.000000e+13   20.0  2000000.0    0.0     C   NaN   NaN
# 1984  5.700000e+13   57.0  5700000.0    0.0     C   NaN   NaN
# 1985  1.500000e+13   15.0  1500000.0    0.0     C   NaN   NaN
# 1986  2.800000e+13   28.0  2800000.0    0.0     C   NaN   NaN
# 1987  4.400000e+13   44.0  4400000.0    0.0     C   NaN   NaN
# 1988  4.600000e+13   46.0  4600000.0    0.0     C   NaN   NaN
# 1989  3.400000e+13   34.0  3400000.0    0.0     C   NaN   NaN
# 1990  3.600000e+13   36.0  3600000.0    0.0     C   NaN   NaN
# 1991  5.000000e+12    5.0   500000.0    0.0     C   NaN   NaN
# 1992  2.200000e+13   22.0  2200000.0    0.0     C   NaN   NaN
# 1993  3.100000e+13   31.0  3100000.0    0.0     C   NaN   NaN
# 1994  5.500000e+13   55.0  5500000.0    0.0     C   NaN   NaN
# ...

# %%
#There's still '*' value, so let's replace it! 
sat2019cali.replace('*', np.nan, inplace=True)

# %%
#remove the unnamed column
sat2019cali.drop(columns=['unnamed: 25', 'cds', 'ccode', 'cdcode', 'scode', 'sname', 'dname', 'year', 'rtype'], inplace=True)

# %%
#rename cname to county
sat2019cali = sat2019cali.rename(columns={'cname': 'county'})

# %%
sat2019cali = sat2019cali.reset_index(drop=True)

# %%
print(sat2019cali.shape)
sat2019cali.info()
# Out:
# (58, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 58 non-null     object
#  1   enroll12               58 non-null     float64
#  2   numtsttakr12           58 non-null     float64
#  3   numerwbenchmark12      55 non-null     object
#  4   pcterwbenchmark12      55 non-null     object
#  5   nummathbenchmark12     55 non-null     object
#  6   pctmathbenchmark12     55 non-null     object
#  7   enroll11               58 non-null     float64
#  8   numtsttakr11           58 non-null     float64
#  9   numerwbenchmark11      55 non-null     object
#  10  pcterwbenchmark11      55 non-null     object
#  11  nummathbenchmark11     55 non-null     object
#  12  pctmathbenchmark11     55 non-null     object
#  13  totnumbothbenchmark12  55 non-null     object
# ...

# %%
for column in sat2019cali.columns[3:7]:
    sat2019cali[column]=sat2019cali[column].apply(lambda x: float(x))

# %%
for column in sat2019cali.columns[9:]:
    sat2019cali[column]=sat2019cali[column].apply(lambda x: float(x))

# %%
#We have converted all the number related rows into float!
sat2019cali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 58 non-null     object
#  1   enroll12               58 non-null     float64
#  2   numtsttakr12           58 non-null     float64
#  3   numerwbenchmark12      55 non-null     float64
#  4   pcterwbenchmark12      55 non-null     float64
#  5   nummathbenchmark12     55 non-null     float64
#  6   pctmathbenchmark12     55 non-null     float64
#  7   enroll11               58 non-null     float64
#  8   numtsttakr11           58 non-null     float64
#  9   numerwbenchmark11      55 non-null     float64
#  10  pcterwbenchmark11      55 non-null     float64
#  11  nummathbenchmark11     55 non-null     float64
#  12  pctmathbenchmark11     55 non-null     float64
#  13  totnumbothbenchmark12  55 non-null     float64
# ...

# %% [markdown]
# ## How do we account for differences in participation?
# - Multiple sources have pointed out that participation rates in SAT appear to be influenced heavily by factors, especially socioeconomic status and income levels. For example, economically disadvantaged students are discouraged from participating in SAT due to reasons such as having difficulty paying for SAT fees, or financial challenges in bearing future university tuition fees. Such reasons may discourage young people from poorer backgrounds from taking the first step in taking the SATs.
#
# - Let's import the CSV file for median household income data by county and clean it!
# - Then we can combine the data with our SAT2019cali dataframe.
#
#
# Resources/references:
# - https://thermtide.com/10448/uncategorized/sat-battles-claim-of-socioeconomic-discrimination/,
# - https://files.eric.ed.gov/fulltext/ED561029.pdf,
# - https://ifs.org.uk/bns/bn133.pdf

# %%
#Let's import a new file to show the median household income by county
hhincome2019 = pd.read_csv('data/Median_Household_Income_by_County.csv')
hhincome2019
# Out:
#                     Median Household Income by County Unnamed: 1  \
# 0                                              County     Income
# 1                                      Alameda County    $99,406
# 2                                       Alpine County    $63,750
# 3                                       Amador County    $62,772
# 4                                        Butte County    $52,537
# 5                                    Calaveras County    $63,158
# 6                                       Colusa County    $59,401
# 7                                 Contra Costa County    $99,716
# 8                                    Del Norte County    $45,283
# 9                                    El Dorado County    $83,377
# 10                                      Fresno County    $53,969
# 11                                       Glenn County    $49,633
# 12                                    Humboldt County    $48,041
# ...

# %%
#let's clean our headings
hhincome2019 = hhincome2019.rename(columns={'Median Household Income by County': 'county', 'Unnamed: 1': 'medianhouseholdincome', 'Unnnamed: 2': 'marginoferror'})

# %%
hhincome2019.head()
# Out:
#            county medianhouseholdincome       Unnamed: 2
# 0          County                Income  Margin Of Error
# 1  Alameda County               $99,406         +/- $921
# 2   Alpine County               $63,750      +/- $17,778
# 3   Amador County               $62,772       +/- $2,756
# 4    Butte County               $52,537       +/- $1,618

# %%
#drop row 59 since it is not relevant for us
hhincome2019 = hhincome2019.drop([59])

# %%
hhincome2019
# Out:
#                     county medianhouseholdincome       Unnamed: 2
# 0                   County                Income  Margin Of Error
# 1           Alameda County               $99,406         +/- $921
# 2            Alpine County               $63,750      +/- $17,778
# 3            Amador County               $62,772       +/- $2,756
# 4             Butte County               $52,537       +/- $1,618
# 5         Calaveras County               $63,158       +/- $4,128
# 6            Colusa County               $59,401       +/- $4,265
# 7      Contra Costa County               $99,716       +/- $1,157
# 8         Del Norte County               $45,283       +/- $5,017
# 9         El Dorado County               $83,377       +/- $2,342
# 10           Fresno County               $53,969         +/- $794
# 11            Glenn County               $49,633       +/- $2,854
# 12         Humboldt County               $48,041       +/- $1,798
# ...

# %%
#let's remove the word county from the county column, and drop the first headings as there are repeated headings.

def replace_word(x):
    x = x.replace(' County','')
    return x
               
hhincome2019['county'] = hhincome2019['county'].apply(lambda x: replace_word(x))
hhincome2019 = hhincome2019.drop([0])

# %%
#let's drop column "unnamed 2" (aka margin of error) as we dont need it for our data analysis 
hhincome2019.drop(columns=['Unnamed: 2'], inplace= True)

# %%
hhincome2019.reset_index(inplace=True, drop=True)

# %%
hhincome2019
# Out:
#              county medianhouseholdincome
# 0           Alameda               $99,406
# 1            Alpine               $63,750
# 2            Amador               $62,772
# 3             Butte               $52,537
# 4         Calaveras               $63,158
# 5            Colusa               $59,401
# 6      Contra Costa               $99,716
# 7         Del Norte               $45,283
# 8         El Dorado               $83,377
# 9            Fresno               $53,969
# 10            Glenn               $49,633
# 11         Humboldt               $48,041
# 12         Imperial               $47,622
# 13             Inyo               $57,316
# 14             Kern               $53,350
# 15            Kings               $57,848
# 16             Lake               $47,040
# 17           Lassen               $56,352
# 18      Los Angeles               $68,044
# 19           Madera               $57,585
# 20            Marin              $115,246
# ...

# %%
#now we need to change the value of medianhousehold income to int, and take out the $ signs and commas
hhincome2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 58 non-null     object
#  1   medianhouseholdincome  58 non-null     object
# dtypes: object(2)
# memory usage: 1.0+ KB

# %%
#to remove $ and commas, and change value type to int
hhincome2019['medianhouseholdincome'] = hhincome2019['medianhouseholdincome'].str.replace(',', '').str.replace('$', '').astype(int)
# Out:
# <ipython-input-62-0c8f0acfc2db>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   hhincome2019['medianhouseholdincome'] = hhincome2019['medianhouseholdincome'].str.replace(',', '').str.replace('$', '').astype(int)

# %%
#we have cleaned up the dataframe for household median income
print(hhincome2019.info())
hhincome2019
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   county                 58 non-null     object
#  1   medianhouseholdincome  58 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB
# None
#              county  medianhouseholdincome
# 0           Alameda                  99406
# 1            Alpine                  63750
# 2            Amador                  62772
# 3             Butte                  52537
# 4         Calaveras                  63158
# 5            Colusa                  59401
# 6      Contra Costa                  99716
# 7         Del Norte                  45283
# 8         El Dorado                  83377
# 9            Fresno                  53969
# 10            Glenn                  49633
# 11         Humboldt                  48041
# ...

# %%
#now we merge sat2019cali to hhincome2019
sat2019cali = sat2019cali.merge(hhincome2019, on = 'county')

# %%
#now that our new sat2019cali contains median household income, we need to further clean up data before data analysis
sat2019cali
# Out:
#              county  enroll12  numtsttakr12  numerwbenchmark12  \
# 0         El Dorado    2226.0         604.0              547.0
# 1       Los Angeles  114618.0       48676.0            30081.0
# 2            Madera    2352.0         442.0              277.0
# 3              Yolo    2299.0         759.0              586.0
# 4              Kern   14229.0        3793.0             2334.0
# 5              Napa    1717.0         555.0              403.0
# 6        Santa Cruz    3239.0         864.0              655.0
# 7            Sierra      23.0           5.0                NaN
# 8        Sacramento   19540.0        6090.0             4138.0
# 9    San Bernardino   31635.0       10544.0             7014.0
# 10        Calaveras     451.0          90.0               81.0
# 11         Mariposa     155.0          36.0               33.0
# 12           Placer    5931.0        1959.0             1709.0
# 13         Tuolumne     518.0          80.0               66.0
# ...

# %%
#we need find out which county has NaN values, and decide to remove them
sat2019cali.sort_values(by= 'numerwbenchmark11', inplace=False, na_position='first')
# Out:
#              county  enroll12  numtsttakr12  numerwbenchmark12  \
# 7            Sierra      23.0           5.0                NaN
# 31           Alpine       0.0           0.0                NaN
# 48            Modoc      87.0          16.0               12.0
# 34             Mono     420.0          37.0               32.0
# 37          Trinity     154.0          13.0                NaN
# 11         Mariposa     155.0          36.0               33.0
# 39           Lassen     283.0          61.0               45.0
# 32           Amador     305.0          53.0               44.0
# 47             Inyo     548.0          88.0               47.0
# 53           Plumas     163.0          34.0               28.0
# 38        Del Norte     363.0          72.0               50.0
# 13         Tuolumne     518.0          80.0               66.0
# 36           Tehama     688.0          91.0               69.0
# 20            Glenn     500.0          90.0               58.0
# ...

# %%
#the three counties with many NaN values is Sierra, Alpine, and Modoc. Let's drop them!
sat2019cali.drop([7,31,48], inplace=True)

# %%
#reset index as the removal of counties will disrupt the index
sat2019cali.reset_index(drop=True)
# Out:
#              county  enroll12  numtsttakr12  numerwbenchmark12  \
# 0         El Dorado    2226.0         604.0              547.0
# 1       Los Angeles  114618.0       48676.0            30081.0
# 2            Madera    2352.0         442.0              277.0
# 3              Yolo    2299.0         759.0              586.0
# 4              Kern   14229.0        3793.0             2334.0
# 5              Napa    1717.0         555.0              403.0
# 6        Santa Cruz    3239.0         864.0              655.0
# 7        Sacramento   19540.0        6090.0             4138.0
# 8    San Bernardino   31635.0       10544.0             7014.0
# 9         Calaveras     451.0          90.0               81.0
# 10         Mariposa     155.0          36.0               33.0
# 11           Placer    5931.0        1959.0             1709.0
# 12         Tuolumne     518.0          80.0               66.0
# 13        Mendocino     988.0         217.0              174.0
# ...

# %%
print(sat2019cali.shape)
sat2019cali
# Out:
# (55, 18)
#              county  enroll12  numtsttakr12  numerwbenchmark12  \
# 0         El Dorado    2226.0         604.0              547.0
# 1       Los Angeles  114618.0       48676.0            30081.0
# 2            Madera    2352.0         442.0              277.0
# 3              Yolo    2299.0         759.0              586.0
# 4              Kern   14229.0        3793.0             2334.0
# 5              Napa    1717.0         555.0              403.0
# 6        Santa Cruz    3239.0         864.0              655.0
# 8        Sacramento   19540.0        6090.0             4138.0
# 9    San Bernardino   31635.0       10544.0             7014.0
# 10        Calaveras     451.0          90.0               81.0
# 11         Mariposa     155.0          36.0               33.0
# 12           Placer    5931.0        1959.0             1709.0
# 13         Tuolumne     518.0          80.0               66.0
# 14        Mendocino     988.0         217.0              174.0
# ...

# %%
#let's create columns to find out the participation rate for grades 11 and 12 respectively
sat2019cali['participation_rate_grade11'] = (sat2019cali['numtsttakr11']/sat2019cali['enroll11'])
sat2019cali['participation_rate_grade12'] = (sat2019cali['numtsttakr12']/sat2019cali['enroll12'])

# %%
sat2019calinew = sat2019cali 
#rename the file

# %%
#Save the file as a new CSV
sat2019calinew.to_csv('sat2019new.csv')

# %%
pd.options.display.float_format = '{:.2f}'.format
sat2019calinew.describe().T
# Out:
#                             count     mean      std      min      25%  \
# enroll12                    55.00  8900.73 17702.91   154.00   677.50
# numtsttakr12                55.00  3098.00  7238.68    13.00   138.00
# numerwbenchmark12           54.00  2156.93  4646.30    28.00   127.25
# pcterwbenchmark12           54.00    74.39     9.89    52.70    66.80
# nummathbenchmark12          54.00  1509.83  3154.05    15.00    76.00
# pctmathbenchmark12          54.00    52.12    13.21    20.27    41.01
# enroll11                    55.00  8631.20 17182.17   112.00   811.50
# numtsttakr11                55.00  3756.62  9813.15    31.00   120.00
# numerwbenchmark11           55.00  2623.55  5954.71    27.00    93.50
# pcterwbenchmark11           55.00    79.21    10.51    47.13    73.76
# nummathbenchmark11          55.00  1974.82  4170.87    23.00    69.50
# pctmathbenchmark11          55.00    63.01    15.28    24.50    50.39
# ...

# %%
sat2019calinew = sat2019calinew.fillna(0)

# %%
sat2019calinew
# Out:
#              county  enroll12  numtsttakr12  numerwbenchmark12  \
# 0         El Dorado   2226.00        604.00             547.00
# 1       Los Angeles 114618.00      48676.00           30081.00
# 2            Madera   2352.00        442.00             277.00
# 3              Yolo   2299.00        759.00             586.00
# 4              Kern  14229.00       3793.00            2334.00
# 5              Napa   1717.00        555.00             403.00
# 6        Santa Cruz   3239.00        864.00             655.00
# 8        Sacramento  19540.00       6090.00            4138.00
# 9    San Bernardino  31635.00      10544.00            7014.00
# 10        Calaveras    451.00         90.00              81.00
# 11         Mariposa    155.00         36.00              33.00
# 12           Placer   5931.00       1959.00            1709.00
# 13         Tuolumne    518.00         80.00              66.00
# 14        Mendocino    988.00        217.00             174.00
# ...

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# ### My Data Dictionary
# =========================
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county**|*object*|SAT 2019 California New|County in the state of California, US|
# |**enroll11**|*float*|SAT 2019 California New|The total number of grade 11 enrollments in SAT 2019|
# |**numtsttakr11**|*float*|SAT 2019 California New|Number of actual Test Takers of Grade 11 |
# |**numerwbenchmark11**|*float*|SAT 2019 California New|The number of grade 11 students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW)|
# |**pcterwbenchmark11**|*float*|SAT 2019 California New|The percentage of grade 11 students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW)|
# |**nummathbenchmark11**|*float*|SAT 2019 California New|The number of grade 11 students who met or exceeded the benchmark for Math|
# |**pctmathbenchmark11**|*float*|SAT 2019 California New|The percentage of grade 11 students who met or exceeded the benchmark for Math|
# |**totnumbothbenchmark11**|*float*|SAT 2019 California New|The total number of grade 11 students who met or exceeded the benchmark for both ERW and Math|
# |**pctbothbenchmark11**|*float*|SAT 2019 California New|The total percentage of grade 11 students who met or exceeded the benchmark for both ERW and Math|
# |**participation_rate_grade11**|*float*|SAT 2019 California New|The percentage of actual test takers out of all grade 11 SAT enrollees (value is shown as approximate decimals e.g. 0.32 = 32% )|
# |**enroll12**|*float*|SAT 2019 California New|The total number of grade 12 enrollments in SAT 2019|
# |**numtsttakr12**|*float*|SAT 2019 California New|Number of actual Test Takers of Grade 12|
# |**numerwbenchmark12**|*float*|SAT 2019 California New|The number of grade 12 students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW)|
# |**pcterwbenchmark12**|*float*|SAT 2019 California New|The percentage of grade 12 students who met or exceeded the benchmark for Evidence-Based Reading & Writing (ERW)|
# |**nummathbenchmark12**|*float*|SAT 2019 California New|The number of grade 12 students who met or exceeded the benchmark for Math|
# |**pctmathbenchmark12**|*float*|SAT 2019 California New|The percentage of grade 12 students who met or exceeded the benchmark for Math|
# |**totnumbothbenchmark12**|*float*|SAT 2019 California New|The total number of grade 12 students who met or exceeded the benchmark for both ERW and Math|
# |**pctbothbenchmark12**|*float*|SAT 2019 California New|The total percentage of grade 12 students who met or exceeded the benchmark for both ERW and Math|
# |**medianhouseholdincome**|*int*|SAT 2019 California New|The median household income based on county (based on 2015 to 2019 American Community Survey 5 years estimates)|
# |**participation_rate_grade12**|*float*|SAT 2019 California New|The percentage of actual test takers out of all grade 12 SAT enrollees (value is shown as approximate decimals e.g. 0.32 = 32% )|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Using a dictionary comprehension to apply to the earlier data frame
sd = dict(zip(sat2017_18_19.columns[1:], sat2017_18_19[sat2017_18_19.columns[1:]].apply(stdev)))

# %%
sd
# Out:
# {'participationrate_2017': 0.3492907076664507,
#  'ebrw_17': 45.21697020437866,
#  'math_17': 84.07255521608297,
#  'total_17': 91.58351056778743,
#  'participationrate_2018': 0.3694661922353942,
#  'ebrw_18': 47.03460978357609,
#  'math_18': 47.30194550378352,
#  'total_18': 93.22742384464433,
#  'participationrate_2019': 0.3836584048685726,
#  'ebrw_19': 45.792378682545134,
#  'math_19': 50.78521461840036,
#  'total_19': 96.24027185617864}

# %%
#Now applying the dictionary comprehension to the data frame of interest! 
sd_for_sat2019calinew = dict(zip(sat2019calinew.columns[1:], sat2019calinew[sat2019calinew.columns[1:]].apply(stdev)))

# %%
sd_for_sat2019calinew
# Out:
# {'enroll12': 17541.23233512146,
#  'numtsttakr12': 7172.569292418544,
#  'numerwbenchmark12': 4570.135640209966,
#  'pcterwbenchmark12': 13.890963010366555,
#  'nummathbenchmark12': 3102.739683751115,
#  'pctmathbenchmark12': 14.721626194757896,
#  'enroll11': 17025.256136799722,
#  'numtsttakr11': 9723.532316435236,
#  'numerwbenchmark11': 5900.326597488041,
#  'pcterwbenchmark11': 10.414183002199728,
#  'nummathbenchmark11': 4132.775849412546,
#  'pctmathbenchmark11': 15.145376878552362,
#  'totnumbothbenchmark12': 2922.9572077516127,
#  'pctbothbenchmark12': 14.682760573188775,
#  'totnumbothbenchmark11': 3929.020886423285,
#  'pctbothbenchmark11': 15.247468448324287,
#  'medianhouseholdincome': 20228.899549239533,
#  'participation_rate_grade11': 0.12747183559292605,
#  'participation_rate_grade12': 0.08850353508271297}

# %%
lowincome = sat2019calinew.sort_values('medianhouseholdincome').head(10)
#we create a variable for the bottom 10 counties with lowest income, so we can check for correlation between median household income and SAT participation rates later. Let's analyze the data further

# %%
#the 10 counties with the lowest median household income. 
#Are the specific counties with lower incomes really have lower participation rates?
lowincome
# Out:
#        county  enroll12  numtsttakr12  numerwbenchmark12  pcterwbenchmark12  \
# 37    Trinity    154.00         13.00               0.00               0.00
# 36     Tehama    688.00         91.00              69.00              75.82
# 19   Siskiyou    462.00        109.00              83.00              76.15
# 38  Del Norte    363.00         72.00              50.00              69.44
# 56       Lake    667.00        167.00             123.00              73.65
# 43   Imperial   3168.00        775.00             540.00              69.68
# 42   Humboldt   1342.00        300.00             250.00              83.33
# 11   Mariposa    155.00         36.00              33.00              91.67
# 20      Glenn    500.00         90.00              58.00              64.44
# 22     Tulare   7558.00       1801.00            1117.00              62.02
#
#     nummathbenchmark12  pctmathbenchmark12  enroll11  numtsttakr11  \
# ...

# %%
# We can also create a variable for the bottom 10 counties with lowest income, so we can check for correlation between median household income and SAT participation rates later.
highincome = sat2019calinew.sort_values('medianhouseholdincome').tail(10)

# %%
highincome
# Out:
#            county  enroll12  numtsttakr12  numerwbenchmark12  \
# 51        Ventura  10750.00       4534.00            2815.00
# 5            Napa   1717.00        555.00             403.00
# 12         Placer   5931.00       1959.00            1709.00
# 15         Orange  41235.00      16061.00           11463.00
# 23        Alameda  17567.00       5946.00            4566.00
# 55   Contra Costa  14593.00       5412.00            3798.00
# 57  San Francisco   4447.00       2256.00            1579.00
# 18          Marin   2647.00        965.00             855.00
# 17      San Mateo   7235.00       3113.00            2410.00
# 50    Santa Clara  21656.00       6920.00            5741.00
#
#     pcterwbenchmark12  nummathbenchmark12  pctmathbenchmark12  enroll11  \
# 51              62.09             2068.00               45.61  10924.00
# 5               72.61              272.00               49.01   1687.00
# 12              87.24             1395.00               71.21   5919.00
# ...

# %%
#We wanna do this to get the overall sense of SAT participation rates across counties for grade 11 and 12 respectively.
overall_participation_rate_11 = sat2019calinew['numtsttakr11'].sum()/sat2019calinew['enroll11'].sum()
overall_participation_rate_12 = sat2019calinew['numtsttakr12'].sum()/sat2019calinew['enroll12'].sum()

# %%
print(overall_participation_rate_11)
print(overall_participation_rate_12)
# Out:
# 0.43523706805753337
# 0.348061445438575

# %%
sat2019calinew.sort_values('participation_rate_grade11')[['county','participation_rate_grade11']].head(10)
#These are the counties with the lowest SAT participate rates in grade 11
# Out:
#       county  participation_rate_grade11
# 47      Inyo                        0.09
# 36    Tehama                        0.11
# 13  Tuolumne                        0.14
# 32    Amador                        0.14
# 52     Kings                        0.16
# 56      Lake                        0.17
# 41      Yuba                        0.18
# 29    Nevada                        0.18
# 44    Shasta                        0.19
# 26    Sutter                        0.19

# %%
sat2019calinew.sort_values('participation_rate_grade11')[['county','participation_rate_grade11']].tail(10)
#These are the counties with the highest SAT participate rates in grade 11
# Out:
#             county  participation_rate_grade11
# 8       Sacramento                        0.42
# 53          Plumas                        0.43
# 23         Alameda                        0.44
# 57   San Francisco                        0.45
# 5             Napa                        0.46
# 51         Ventura                        0.50
# 9   San Bernardino                        0.52
# 2           Madera                        0.56
# 1      Los Angeles                        0.61
# 50     Santa Clara                        0.67

# %%
sat2019calinew.sort_values('participation_rate_grade12')[['county','participation_rate_grade12']].head(10)
#These are the counties with the lowest SAT participate rates in grade 12
# Out:
#       county  participation_rate_grade12
# 37   Trinity                        0.08
# 34      Mono                        0.09
# 29    Nevada                        0.10
# 36    Tehama                        0.13
# 13  Tuolumne                        0.15
# 47      Inyo                        0.16
# 32    Amador                        0.17
# 44    Shasta                        0.18
# 20     Glenn                        0.18
# 41      Yuba                        0.18

# %%
sat2019calinew.sort_values('participation_rate_grade12')[['county','participation_rate_grade12']].tail(10)
#These are the counties with the highest SAT participate rates in grade 12
# Out:
#             county  participation_rate_grade12
# 9   San Bernardino                        0.33
# 23         Alameda                        0.34
# 18           Marin                        0.36
# 55    Contra Costa                        0.37
# 15          Orange                        0.39
# 54       Riverside                        0.41
# 51         Ventura                        0.42
# 1      Los Angeles                        0.42
# 17       San Mateo                        0.43
# 57   San Francisco                        0.51

# %%
sat2019calinew.sort_values('pctbothbenchmark11')[['county','pctbothbenchmark11']].tail(10)
#These are not part of the problem statement, but we are curious to find out the top 10 performing counties based on the counties' percentage of grade 11 students who met or exceeded the benchmark for both ERW and Math
# Out:
#              county  pctbothbenchmark11
# 55     Contra Costa               74.71
# 16  San Luis Obispo               75.32
# 17        San Mateo               77.59
# 44           Shasta               79.85
# 12           Placer               81.56
# 18            Marin               81.72
# 32           Amador               85.42
# 0         El Dorado               86.82
# 11         Mariposa               87.18
# 29           Nevada               87.65

# %%
sat2019calinew.sort_values('pctbothbenchmark11')[['county','pctbothbenchmark11']].head(10)
# #These are not part of the problem statement, but we are curious to find out the bottom 10 performing counties based on the counties' percentage of grade 11 students who met or exceeded the benchmark for both ERW and Math
# Out:
#             county  pctbothbenchmark11
# 2           Madera               22.71
# 9   San Bernardino               34.63
# 24          Fresno               35.99
# 1      Los Angeles               36.03
# 56            Lake               37.30
# 33          Merced               40.76
# 54       Riverside               41.15
# 47            Inyo               43.21
# 20           Glenn               45.56
# 22          Tulare               46.14

# %%
sat2019calinew.sort_values('pctbothbenchmark12')[['county','pctbothbenchmark12']].tail(11)
#These are not part of the problem statement, but we are curious to find out the top 10 performing counties based on the counties' percentage of grade 12 students who met or exceeded the benchmark for both ERW and Math
# Out:
#              county  pctbothbenchmark12
# 32           Amador               62.26
# 16  San Luis Obispo               63.65
# 44           Shasta               63.73
# 53           Plumas               64.71
# 10        Calaveras               66.67
# 50      Santa Clara               66.76
# 29           Nevada               68.28
# 18            Marin               68.81
# 12           Placer               68.91
# 11         Mariposa               72.22
# 0         El Dorado               73.18

# %%
sat2019calinew.sort_values('pctbothbenchmark12')[['county','pctbothbenchmark12']].head(10)
#These are not part of the problem statement, but we are curious to find out the bottom 10 performing counties based on the counties' percentage of grade 12 students who met or exceeded the benchmark for both ERW and Math
# Out:
#        county  pctbothbenchmark12
# 37    Trinity                0.00
# 46     Colusa               18.92
# 20      Glenn               27.78
# 2      Madera               28.73
# 33     Merced               29.12
# 47       Inyo               31.82
# 27   Monterey               32.43
# 22     Tulare               32.70
# 52      Kings               33.86
# 54  Riverside               34.11

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#let's plot a boxplot to see 

fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

bp = ax.boxplot(sat2019calinew['medianhouseholdincome'], patch_artist = True,
                notch ='True', vert = 0)
plt.title("Fig 2: Box plot for Household Median Income across Counties in California, US");

# %%
sat2019calinew['medianhouseholdincome'].describe()
# Out:
# count       55.00
# mean     68472.44
# std      20415.34
# min      40846.00
# 25%      53820.50
# 50%      62772.00
# 75%      81245.00
# max     124055.00
# Name: medianhouseholdincome, dtype: float64

# %%
#The box plot describes the household median income, and the describe method helps to understand the box plot in detail.

# %% [markdown]
# ## Back to whether participation rates are influenced by household income levels...
# - We are here to examine whether there is a correlation between participation rates and household income levels.
# - We will first execute a heatmap to examine this.

# %%
fig, ax = plt.subplots(figsize=(15, 12))

# color map
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)

#corr
sat2019calinew_corr = sat2019calinew.corr()

# mask
mask = np.triu(np.ones_like(sat2019calinew_corr, dtype=np.bool))

# adjust mask and df
mask = mask[1:, :-1]
corr = sat2019calinew_corr.iloc[1:,:-1].copy()

# plot heatmap
ax = sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap=cmap,
           vmin=-1, vmax=1, cbar_kws={"shrink": .8})

plt.yticks(rotation=45)
plt.xticks(rotation=75)
ax.set_title('Fig 3: Correlation Heatmap for SAT participation in 2019 in California Data\n');
# Out:
# <ipython-input-97-d5d241ddba6e>:10: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(sat2019calinew_corr, dtype=np.bool))

# %% [markdown]
# **Interpretation**
#
# *Median household income and participation rates amongst grade 12 is positively correlated, with a number of 0.68*
#
# *Similarly, median household income and participation rates amongst grade 11 is positively correlated as well, with a number of 0.57*
#
# *Surprisingly, there is a low correlation between median household income and total percentage of grade 12 students who met or exceeded the benchmark for both ERW and Math (number of 0.38), as well as total percentage of grade 11 students who met or exceeded the benchmark for both ERW and Math (number of 0.36).*
#
# *Let's visualize this correlation between median household income and participation rates, and between median household income and performance a bit better.*

# %%
#let's plot a linear regression plot to find out the correlation between median household income, and participation rates for grade 11 and 12 respectively. 
plt.figure(figsize=(15,14))
sns.set(style="darkgrid")

sns.regplot(x='medianhouseholdincome', y='participation_rate_grade12', data = sat2019cali,
           marker="+", scatter_kws={'s':120, 'color':'skyblue'}, line_kws={'color': 'red'},  ci = None);
sns.regplot(x='medianhouseholdincome', y='participation_rate_grade11', data = sat2019cali, 
            scatter_kws={'s':40, 'color':'limegreen'}, line_kws={'color': 'purple'},  ci = None);

plt.legend(["Participation rate Grade 12 with blue cross", "Participation rate Grade 11 with green dots"])

plt.xlabel("Median Household Income")
plt.ylabel("SAT Participation Rate");

plt.title("Fig 4:Regplot comparing Participation Rate (Grade 11 and 12) and Household Median Income across Counties in California, US");

plt.savefig('regplot1.png')

# %% [markdown]
# - Here we can see that counties with lower median household incomes are correlated with lower SAT participation rates for both grades.
# - The converse is true for counties with higher median household incomes.

# %%
#let's plot a linear regression plot to find out the correlation between median household income, and total percentage of students who met or exceeded the benchmark for both ERW and Math for grade 11 and 12 respectively. 

plt.figure(figsize=(15,14))
sns.set(style="darkgrid")

sns.regplot(x='medianhouseholdincome', y='pctbothbenchmark11', data = sat2019cali,
           marker="+", scatter_kws={'s':120, 'color':'violet'}, line_kws={'color': 'red'},  ci = None);
sns.regplot(x='medianhouseholdincome', y='pctbothbenchmark12', data = sat2019cali, 
            scatter_kws={'s':40, 'color':'orange'}, line_kws={'color': 'purple'},  ci = None);

plt.legend(["Total % of students doing well in Grade 11 with purple cross", "Total % of students doing well in Grade 12 with orange dots"])

plt.xlabel("Median Household Income")
plt.ylabel("Total percentage of students who met or exceeded the benchmark for both ERW and Math for grade 11 and 12 respectively");

plt.title("Fig 5: Regplot comparing SAT performance(Grade 11 and 12) and Household Median Income across Counties in California, US");

# %% [markdown]
# - From this scatterplot and regression line, we see that the data are much more spread out than participation rate data, and that while a line has been fit to the data (indicating that as household income increases, so does the performance level), the linear relationship between the two appears to be weaker than the linear relationship between participation rates and income level.

# %% [markdown]
# ## After examining the correlation between median household income criteria and variables including participation rates and performance levels....
# - Since there is a correlation between median household income and SAT participation rates, let's analyze the data further
# - Let's create a barchart using the lowincome and highincome dataframes that we generated earlier on, and compare it with the overall participation rate in its grade level.

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=45, ha = 'right')
plt.title('Fig 6: SAT Participation Rates for Grade 11 by County')
plt.xlabel('County')
plt.ylabel('Participation Rate')

#plt.grid(True)
plt.tight_layout
plt.bar(lowincome.sort_values(by='participation_rate_grade11')['county'],
        lowincome.sort_values(by='participation_rate_grade11')['participation_rate_grade11'],
        label = '10 Poorest Counties by Median Household Income', color = 'skyblue')
plt.axhline(overall_participation_rate_11, color = 'red', label = 'California Average Grade 11 SAT Participation Rate', linestyle = '-.')
offset = 10
plt.text(offset, overall_participation_rate_11, overall_participation_rate_11, color = 'grey')
plt.legend(loc='upper left')

plt.ylim(0, 0.6)
# Out:
# (0.0, 0.6)

# %% [markdown]
# #### Here we can see that the the percentage of participation amongst grade 11 students in the  poorest 10 counties in California  fall below the overall participation rates across the state of California.

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=45, ha = 'right')
plt.title('Fig 7: SAT Participation Rates for Grade 12 by County')
plt.xlabel('County')
plt.ylabel('Participation Rate')

#plt.grid(True)
plt.tight_layout
plt.bar(lowincome.sort_values(by='participation_rate_grade12')['county'],
        lowincome.sort_values(by='participation_rate_grade12')['participation_rate_grade12'],
        label = '10 Poorest Counties by Median Household Income', color = 'pink')
plt.axhline(overall_participation_rate_12, color = 'red', label = 'California Average Grade 12 SAT Participation Rate', linestyle = '-.')
offset = 10
plt.text(offset, overall_participation_rate_12, overall_participation_rate_12, color = 'grey')
plt.legend(loc='upper left')

plt.ylim(0, 0.6)
# Out:
# (0.0, 0.6)

# %% [markdown]
# #### Similarly, we can see that the the percentage of participation amongst grade 12 students in the  poorest 10 counties in California  fall below the overall participation rates across the state of California.

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=45, ha = 'right')
plt.title('Fig 8: SAT Participation Rates for Grade 11 by County')
plt.xlabel('County')
plt.ylabel('Participation Rate')

#plt.grid(True)
plt.tight_layout
plt.bar(highincome.sort_values(by='participation_rate_grade11')['county'],
        highincome.sort_values(by='participation_rate_grade11')['participation_rate_grade11'],
        label = '10 Richest Counties by Median Household Income', color = 'limegreen')
plt.axhline(overall_participation_rate_11, color = 'red', label = 'California Average Grade 11 SAT Participation Rate', linestyle = '-.')
offset = 10
plt.text(offset, overall_participation_rate_11, overall_participation_rate_11, color = 'grey')
plt.legend(loc='upper left')

plt.ylim(0, 0.6)
# Out:
# (0.0, 0.6)

# %% [markdown]
# #### Conversely, we can see that the the percentage of participation amongst grade 11 students in the richest 10 counties in California are close to/exceed the overall participation rates across the state of California

# %%
plt.figure(figsize=(10,7))
plt.xticks(rotation=45, ha = 'right')
plt.title('Fig 9: SAT Participation Rates for Grade 12 by County')
plt.xlabel('County')
plt.ylabel('Participation Rate')

#plt.grid(True)
plt.tight_layout
plt.bar(highincome.sort_values(by='participation_rate_grade12')['county'],
        highincome.sort_values(by='participation_rate_grade12')['participation_rate_grade12'],
        label = '10 Richest Counties by Median Household Income', color = 'gold')
plt.axhline(overall_participation_rate_12, color = 'red', label = 'California Average Grade 12 SAT Participation Rate', linestyle = '-.')
offset = 10
plt.text(offset, overall_participation_rate_12, overall_participation_rate_12, color = 'grey')
plt.legend(loc='upper left')

plt.ylim(0, 0.6)
# Out:
# (0.0, 0.6)

# %% [markdown]
# #### We can observe that the the percentage of participation amongst grade 12 students in the richest 10 counties in California are close to/exceed the overall participation rates across the state of California.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# *We would like to make various recommendations based on our findings above.*
#
# `Recommendation 1`:
# - `Increase access to SAT participation by removing financial barriers` Given that the ability to pay for SAT fees might likely be a barrier to SAT participation, we propose offering SAT free of charge for all grade 11 students to ensure universal SAT participation. This would also boost their confidence in the event they wish to re-attempt SAT in grade 12.
#
# `Recommendation 2`:
# - `Offer SAT during regular school hours` SAT are conducted mostly on Saturdays, which may likely deter low-income individuals from participating in SAT since they are more likely to have part-time jobs, family responsibilities, etc. We propose offering SAT to be conducted during regular school hours to increase their access to SAT participation.
#
# `Recommendation 3`:
# - `Offer free access to extra learning materials` Students from lower-income counties, unlike their richer counterparts, may likely have less access to additional learning materials such as SAT online courses and prep classes. Consequently, these students may become less motivated to participate in SAT. We propose offering free access to these learning materials to low-income students to increase their motivation and readiness to take SAT.
#
# `Recommendation 4`:
# - `Create a college-going culture` Students from lower-income counties are more likely than their higher-income counterparts to have social and language barriers, less access to information on college, less exploration because of low expectations and underestimation of the amount of financial help available in college. These factors may possibly deter participation in SAT. We propose 1) training to school staff on how to begin promoting high standards and expectations for students and families to achieve at a higher level, as well as 2) academic planning for college and career readiness and college, career exploration and selection processes.
#
#
# #### *References*
# - https://www.census.gov/search-results.html?q=california+median+income&page=1&stateGeo=none&searchtype=web&cssp=SERP&_charset_=UTF-8
# - https://files.eric.ed.gov/fulltext/ED561029.pdf
# - https://ifs.org.uk/bns/bn133.pdf
# - https://thermtide.com/10448/uncategorized/sat-battles-claim-of-socioeconomic-discrimination/
# - https://www.statista.com/statistics/183497/population-in-the-federal-states-of-the-us/
# - https://www.statista.com/statistics/1036120/public-high-school-enrollment-state-us/)

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
