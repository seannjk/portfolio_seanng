# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** For us to improve the participation rates of SAT scores across all states, we need to see if there are any states with significant increase in participation rates over the years, and find out what education policies related to ACT/SAT have changed over these years.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:**
# ## Problem statement:
# - The SAT, which is administered by the College board, is a standardized test that is used for college admissions in the U.S. As the board of directors on the Educational Testing Services under the College Board, we assert that participation in SAT test may likely translate to fair evaluations on students' readiness for college/career, increase their chances of gaining admission to good schools and subsequent upward social mobility in the long-term. We are especially concerned with low SAT participation rates amongst students from poorer socio-economic counties in California, U.S, and would like to propose best practices to improve SAT participation amongst students from low socio-economic counties.
#
#
# outline:
# 1. Show graphs to show the participation rates of US.
# 2. Critique that this participate rate does not show specifically the make up of poor vs rich participation.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*
#
# sat_2019_ca.csv

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
import math

# %%
# Code:

def mean_calculation(num):
    return sum(num) / len(num)

mean_calculation([1,2,6])
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def variance(data):
    n = len(data)          # Number of observations
    mean = sum(data) / n # Mean of the data
    deviations = [(x - mean) ** 2 for x in data] # Square deviations
    variance = sum(deviations) / n
    return variance

def stdev(data):
    var = variance(data)
    std_dev = math.sqrt(var)
    return std_dev

stdev([4,4,4,4,4,4])
# Out:
# 0.0

# %% [markdown]
# 3. Data cleaning function:
#
# Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def clean_data(n):
    if n != 'NaN':
        return (float(n.rstrip("%")))/100

# %%
clean_data('23.5%')
# Out:
# 0.235

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %%
#*All libraries used should be added here*

import scipy.stats as stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import re
from IPython.display import display_html

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
def custom_pallete(custom_colors):
    customPalette = sns.set_palette(sns.color_palette(custom_colors))
    sns.palplot(sns.color_palette(custom_colors),size=1.2)
    plt.tick_params(axis='both', labelsize=0, length = 0)

# %%
acqua = ["#E4F3E0","#B5DEC8","#9CC7B0","#84B099","#CFB384","#F7BF7D","#CA8D89","#8959B9","#973276"]
contrast =["#38618C", "#FFCD70", "#E26D5C", '#723D46', '#472D30']
custom_pallete(acqua)

# %%
act2017 = pd.read_csv('data/act_2017.csv')
act2018 = pd.read_csv('data/act_2018.csv')
act2019 = pd.read_csv('data/act_2017.csv')
act2019cali = pd.read_csv('data/act_2019_ca.csv')

sat2017 = pd.read_csv('data/sat_2017.csv')
sat2018 = pd.read_csv('data/sat_2018.csv')
sat2019 = pd.read_csv('data/sat_2019.csv')
sat2019cali = pd.read_csv('data/sat_2019_ca.csv')

# %%
sat2019
# Out:
#                    State Participation Rate  EBRW  Math  Total
# 0                Alabama                 7%   583   560   1143
# 1                 Alaska                41%   556   541   1097
# 2                Arizona                31%   569   565   1134
# 3               Arkansas                 6%   582   559   1141
# 4             California                63%   534   531   1065
# 5               Colorado               100%   518   506   1024
# 6            Connecticut               100%   529   516   1046
# 7               Delaware               100%   499   486    985
# 8   District of Columbia                94%   495   480    975
# 9                Florida               100%   516   483    999
# 10               Georgia                71%   538   519   1058
# 11                Hawaii                54%   550   550   1100
# 12                 Idaho               100%   505   488    993
# 13              Illinois               100%   509   504   1013
# ...

# %%
sat2018
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
#sat2019['state'].isin(sat2018['State']).value_counts()
##check difference in columns

# %%
#lis = []
#unique2018 = sat2018['state'].unique()

#for each_value in sat2019['state']:
#    if each_value in unique2018:
#        continue
#    else:
#        lis.append(each_value)
        
#    print(lis)

#This shows the two countries that are newly added to SAT2019!

# %%
#do the same for sat2018 and sat2017

sat2018.columns = sat2018.columns.str.lower()
sat2018.rename(columns = {'participation': 'participation_rate'}, inplace = True)                         
sat2018['participation_rate'] = sat2018['participation_rate'].str.replace("%", '').astype(float)

# %%
sat2018
# Out:
#                    state  participation_rate  \
# 0                Alabama                 6.0
# 1                 Alaska                43.0
# 2                Arizona                29.0
# 3               Arkansas                 5.0
# 4             California                60.0
# 5               Colorado               100.0
# 6            Connecticut               100.0
# 7               Delaware               100.0
# 8   District of Columbia                92.0
# 9                Florida                56.0
# 10               Georgia                70.0
# 11                Hawaii                56.0
# 12                 Idaho               100.0
# 13              Illinois                99.0
# 14               Indiana                63.0
# 15                  Iowa                 3.0
# 16                Kansas                 4.0
# 17              Kentucky                 4.0
# 18             Louisiana                 4.0
# 19                 Maine                99.0
# ...

# %%
sat2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   state                               51 non-null     object
#  1   participation_rate                  51 non-null     float64
#  2   evidence-based reading and writing  51 non-null     int64
#  3   math                                51 non-null     int64
#  4   total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
#now for sat2017

sat2017.columns = sat2017.columns.str.lower()
sat2017.rename(columns = {'participation': 'participation_rate', "evidence-based reading and writing": "ebrw"}, inplace=True)
sat2017['participation_rate'] = sat2017['participation_rate'].str.replace("%", '').astype(float)

# %%
sat2017
# Out:
#                    state  participation_rate  ebrw  math  total
# 0                Alabama                 5.0   593   572   1165
# 1                 Alaska                38.0   547   533   1080
# 2                Arizona                30.0   563   553   1116
# 3               Arkansas                 3.0   614   594   1208
# 4             California                53.0   531   524   1055
# 5               Colorado                11.0   606   595   1201
# 6            Connecticut               100.0   530   512   1041
# 7               Delaware               100.0   503   492    996
# 8   District of Columbia               100.0   482   468    950
# 9                Florida                83.0   520   497   1017
# 10               Georgia                61.0   535   515   1050
# 11                Hawaii                55.0   544   541   1085
# 12                 Idaho                93.0   513   493   1005
# 13              Illinois                 9.0   559   556   1115
# ...

# %%
print(f'sat2017_dataframe shape: {sat2017.shape}')
print(f'sat2018_dataframe shape: {sat2018.shape}')
print(f'sat2019_dataframe shape: {sat2019.shape}')
# Out:
# sat2017_dataframe shape: (51, 5)
# sat2018_dataframe shape: (51, 5)
# sat2019_dataframe shape: (53, 5)

# %%
sat2017_18 = pd.merge(left = sat2017, right = sat2018, on = "state")

# %%
sat2017_18.rename(columns = {'participation_rate_x': 'participationrate2017', 'ebrw_x': 'ebrw17', 'math_x': 'math17',
                            'total_x': 'total_17', 'participation_rate_y': 'participationrate2018', 'ebrw_y': 'ebrw18', 'math_y' : 'math18', 'total_y': 'total_18'}, inplace=True )

# %%
sat2017_18
# Out:
#                    state  participationrate2017  ebrw  math17  total_17  \
# 0                Alabama                    5.0   593     572      1165
# 1                 Alaska                   38.0   547     533      1080
# 2                Arizona                   30.0   563     553      1116
# 3               Arkansas                    3.0   614     594      1208
# 4             California                   53.0   531     524      1055
# 5               Colorado                   11.0   606     595      1201
# 6            Connecticut                  100.0   530     512      1041
# 7               Delaware                  100.0   503     492       996
# 8   District of Columbia                  100.0   482     468       950
# 9                Florida                   83.0   520     497      1017
# 10               Georgia                   61.0   535     515      1050
# 11                Hawaii                   55.0   544     541      1085
# ...

# %%
#now I want to compare the mean participation rate in 2017 and 2018 
print(round(sat2017_18['participationrate2017'].mean(),2))
print(round(sat2017_18['participationrate2018'].mean(), 2))

plt.figure(figsize=(6, 4)) # recap: shift+tab for parameter details (width, height)

plt.bar(x=['2017', '2018'], # We have to specify our X labels/location.
        height=[sat2017_18['participationrate2017'].mean(), sat2017_18['participationrate2018'].mean()],  color=['yellow', 'mediumseagreen' ], edgecolor='cyan') # We have to specify the Y height.

# Add a title and show the plot.
plt.title('2017 vs. 2018 Participation rates', {'fontsize': 15});
plt.xlabel('SAT participation rate based on year')
plt.ylabel('Participation rate in %');
# Out:
# 39.8
# 45.75

# %%
sat2019.columns = sat2019.columns.str.lower()
sat2019["participation rate"] = sat2019['participation rate'].str.replace("%", "")
sat2019.rename(columns = {"participation rate" : "participation_rate", "evidence-based reading and writing": "ebrw"}, inplace=True )

# %%
sat2019
# Out:
#                    state participation_rate  ebrw  math  total
# 0                Alabama                  7   583   560   1143
# 1                 Alaska                 41   556   541   1097
# 2                Arizona                 31   569   565   1134
# 3               Arkansas                  6   582   559   1141
# 4             California                 63   534   531   1065
# 5               Colorado                100   518   506   1024
# 6            Connecticut                100   529   516   1046
# 7               Delaware                100   499   486    985
# 8   District of Columbia                 94   495   480    975
# 9                Florida                100   516   483    999
# 10               Georgia                 71   538   519   1058
# 11                Hawaii                 54   550   550   1100
# 12                 Idaho                100   505   488    993
# 13              Illinois                100   509   504   1013
# ...

# %%
sat2019['participation_rate'].replace('—', np.nan, inplace=True)

# %%
sat2019['participation_rate'] = sat2019['participation_rate'].astype(float)

# %%
sat2019['participation_rate'].mean()
# Out:
# 49.05882352941177

# %%
#now I want to compare the mean participation rate in 2017 and 2018 and 2019
print(round(sat2017_18['participationrate2017'].mean(),2))
print(sat2017_18['participationrate2018'].mean())
print(sat2019['participation_rate'].mean())

plt.figure(figsize=(6, 4)) # recap: shift+tab for parameter details (width, height)

plt.bar(x=['2017', '2018', '2019'], # We have to specify our X labels/location.
        height=[sat2017_18['participationrate2017'].mean(), sat2017_18['participationrate2018'].mean(), sat2019['participation_rate'].mean()], color=['yellow', 'mediumseagreen', 'pink' ], edgecolor='cyan') # We have to specify the Y height.

# Add a title and show the plot.
plt.title('2017 vs. 2018 vs. 2019 Participation rates', {'fontsize': 15});
plt.xlabel('Participation rate based on year')
plt.ylabel('Participation rate in %');
# Out:
# 39.8
# 45.745098039215684
# 49.05882352941177

# %%
sns.lmplot(x='participation_rate', y='total', data=sat2017)
sns.lmplot(x='participation_rate', y='total', data=sat2018)
sns.lmplot(x='participation_rate', y='total', data=sat2019);

# %%
sat2017_18.describe()
# Out:
#        participationrate2017        ebrw      math17     total_17  \
# count              51.000000   51.000000   51.000000    51.000000
# mean               39.803922  569.117647  547.627451  1126.098039
# std                35.276632   45.666901   84.909119    92.494812
# min                 2.000000  482.000000   52.000000   950.000000
# 25%                 4.000000  533.500000  522.000000  1055.500000
# 50%                38.000000  559.000000  548.000000  1107.000000
# 75%                66.000000  613.000000  599.000000  1212.000000
# max               100.000000  644.000000  651.000000  1295.000000
#
#        participationrate2018  evidence-based reading and writing      math18  \
# count              51.000000                           51.000000   51.000000
# mean               45.745098                          563.686275  556.235294
# std                37.314256                           47.502627   47.772623
# ...

# %%
sat2019.describe()
# Out:
#        participation_rate        ebrw        math        total
# count           51.000000   53.000000   53.000000    53.000000
# mean            49.058824  558.000000  548.471698  1106.528302
# std             38.747600   47.554422   53.785044   100.994784
# min              2.000000  483.000000  445.000000   935.000000
# 25%              5.500000  518.000000  506.000000  1024.000000
# 50%             54.000000  550.000000  545.000000  1097.000000
# 75%             82.000000  610.000000  596.000000  1200.000000
# max            100.000000  636.000000  648.000000  1284.000000

# %% [markdown]
# ## Analysis
#
# - Based on the descriptive statistics above, an increase in the participation rate is noted from year 2017 to 2019 (from 38% in 2017, to 45% in 2018 and 49% in 2019).
# - The three biggest largest states - Alaska, California and Texas - surprisingly did not make up for the majority of participation.
# - It is even more surprising to note that California, being ranked top 3 largest states, comprise of 1.95 million students enrolled in public high schools in California, the highest figure in the United States (https://www.statista.com/statistics/1036120/public-high-school-enrollment-state-us/).
# -

# %%
sat2019cali.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
sat2019cali.shape
# Out:
# (2580, 26)

# %%
sat2019cali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %%
sat2019cali.columns = sat2019cali.columns.str.lower()

# %%
sat2019cali
# Out:
#                cds  ccode     cdcode      scode rtype  \
# 0     6.615981e+12    6.0   661598.0   630046.0     S
# 1     6.616061e+12    6.0   661606.0   634758.0     S
# 2     1.964733e+13   19.0  1964733.0  1930924.0     S
# 3     1.964733e+13   19.0  1964733.0  1931476.0     S
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# ...            ...    ...        ...        ...   ...
# 2575  5.772678e+13   57.0  5772678.0        0.0     D
# 2576  7.000000e+12    7.0   700000.0        0.0     C
# 2577  1.700000e+13   17.0  1700000.0        0.0     C
# 2578  3.800000e+13   38.0  3800000.0        0.0     C
# 2579           NaN    NaN        NaN        NaN   NaN
#
#                         sname                dname          cname  enroll12  \
# 0     Colusa Alternative Home       Colusa Unified         Colusa      18.0
# 1             Maxwell Sr High      Maxwell Unified         Colusa      29.0
# 2         Belmont Senior High  Los Angeles Unified    Los Angeles     206.0
# ...

# %%
sat2019cali['cname'].value_counts() #check the number of countys since this is our variable of interest
# Out:
# Los Angeles            548
# San Diego              196
# San Bernardino         132
# Riverside              125
# Orange                 119
# Alameda                 94
# Sacramento              92
# Fresno                  88
# Santa Clara             81
# Contra Costa            63
# San Joaquin             61
# Kern                    58
# Sonoma                  50
# Stanislaus              50
# Tulare                  48
# Ventura                 47
# Santa Barbara           38
# Monterey                37
# San Mateo               36
# Placer                  34
# Mendocino               31
# Butte                   27
# Santa Cruz              27
# Merced                  27
# Shasta                  27
# Humboldt                27
# Solano                  26
# San Francisco           26
# San Luis Obispo         25
# Sutter                  23
# Madera                  22
# Imperial                20
# Kings                   19
# Marin                   18
# ...

# %%
sat2019cali['cname'].unique()
# Out:
# array(['Colusa', 'Los Angeles', 'Orange', 'Riverside', 'Imperial',
#        'San Bernardino', 'Kern', 'San Diego', 'Fresno', 'San Joaquin',
#        'Nevada', 'San Mateo', 'Contra Costa', 'Humboldt', 'Placer',
#        'Alameda', 'Glenn', 'Sacramento', 'San Francisco', 'Marin',
#        'Santa Barbara', 'El Dorado', 'Merced', 'Siskiyou', 'Madera',
#        'Sonoma', 'Trinity', 'Tulare', 'Santa Clara', 'Solano',
#        'San Luis Obispo', 'Stanislaus', 'Ventura', 'Santa Cruz', 'Lassen',
#        'Calaveras', 'Monterey', 'Modoc', 'Yolo', 'Tehama', 'Butte',
#        'Tuolumne', 'Sutter', 'Mendocino', 'Lake', 'Amador', 'Kings',
#        'Napa', 'Sierra', 'Shasta', 'Del Norte', 'San Benito', 'Inyo',
#        'Yuba', 'Plumas', 'Mono', 'Mariposa', 'Alpine',
#        'State of California', nan], dtype=object)

# %%
sat2019cali['cname'].nunique()
# Out:
# 59

# %%
hhincome2019 = pd.read_csv('data/Median_Household_Income_by_County.csv')
hhincome2019
# Out:
#                     Median Household Income by County Unnamed: 1  \
# 0                                              County     Income
# 1                                      Alameda County    $99,406
# 2                                       Alpine County    $63,750
# 3                                       Amador County    $62,772
# 4                                        Butte County    $52,537
# 5                                    Calaveras County    $63,158
# 6                                       Colusa County    $59,401
# 7                                 Contra Costa County    $99,716
# 8                                    Del Norte County    $45,283
# 9                                    El Dorado County    $83,377
# 10                                      Fresno County    $53,969
# 11                                       Glenn County    $49,633
# 12                                    Humboldt County    $48,041
# ...

# %%
hhincome2019 = hhincome2019.rename(columns={'Median Household Income by County': 'county', 'Unnamed: 1': 'medianhouseholdincome', 'Unnnamed: 2': 'marginoferror'})

# %%
hhincome2019.head()
# Out:
#            county medianhouseholdincome       Unnamed: 2
# 0          County                Income  Margin Of Error
# 1  Alameda County               $99,406         +/- $921
# 2   Alpine County               $63,750      +/- $17,778
# 3   Amador County               $62,772       +/- $2,756
# 4    Butte County               $52,537       +/- $1,618

# %%
hhincome2019 = hhincome2019.drop([59])

# %%
hhincome2019
# Out:
#                     county medianhouseholdincome       Unnamed: 2
# 0                   County                Income  Margin Of Error
# 1           Alameda County               $99,406         +/- $921
# 2            Alpine County               $63,750      +/- $17,778
# 3            Amador County               $62,772       +/- $2,756
# 4             Butte County               $52,537       +/- $1,618
# 5         Calaveras County               $63,158       +/- $4,128
# 6            Colusa County               $59,401       +/- $4,265
# 7      Contra Costa County               $99,716       +/- $1,157
# 8         Del Norte County               $45,283       +/- $5,017
# 9         El Dorado County               $83,377       +/- $2,342
# 10           Fresno County               $53,969         +/- $794
# 11            Glenn County               $49,633       +/- $2,854
# 12         Humboldt County               $48,041       +/- $1,798
# ...

# %%
sat2019cali.isnull().sum().plot(kind='barh') #using a barchart to see the number of missing values
plt.title('Count of Missing Values');

# %%
sat2019cali.isnull().sum() #there is many missing values around!!
# Out:
# cds                         1
# ccode                       1
# cdcode                      1
# scode                       1
# rtype                       1
# sname                     598
# dname                      59
# cname                       1
# enroll12                    1
# numtsttakr12                1
# numerwbenchmark12         276
# pcterwbenchmark12         276
# nummathbenchmark12        276
# pctmathbenchmark12        276
# enroll11                    1
# numtsttakr11                1
# numerwbenchmark11         311
# pcterwbenchmark11         311
# nummathbenchmark11        311
# pctmathbenchmark11        311
# totnumbothbenchmark12     276
# pctbothbenchmark12        276
# totnumbothbenchmark11     311
# pctbothbenchmark11        311
# year                        1
# unnamed: 25              2580
# dtype: int64

# %%
sat2019cali.columns
# Out:
# Index(['cds', 'ccode', 'cdcode', 'scode', 'rtype', 'sname', 'dname', 'cname',
#        'enroll12', 'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
#        'nummathbenchmark12', 'pctmathbenchmark12', 'enroll11', 'numtsttakr11',
#        'numerwbenchmark11', 'pcterwbenchmark11', 'nummathbenchmark11',
#        'pctmathbenchmark11', 'totnumbothbenchmark12', 'pctbothbenchmark12',
#        'totnumbothbenchmark11', 'pctbothbenchmark11', 'year', 'unnamed: 25'],
#       dtype='object')

# %%
sat2019cali['numerwbenchmark11'].isnull
# Out:
# <bound method Series.isnull of 0        NaN
# 1          *
# 2         42
# 3         97
# 4          *
#         ...
# 2575     454
# 2576    4583
# 2577      94
# 2578    1702
# 2579     NaN
# Name: numerwbenchmark11, Length: 2580, dtype: object>

# %%
# see all * values, * is causing the series to become objects
sat2019cali['numerwbenchmark11'].sort_values(ascending=True)
# Out:
# 1         *
# 1363      *
# 1364      *
# 455       *
# 1369      *
#        ...
# 2540    NaN
# 2571    NaN
# 2572    NaN
# 2573    NaN
# 2579    NaN
# Name: numerwbenchmark11, Length: 2580, dtype: object

# %%
# convert all * values to np.nan using list comprehension
sat2019cali['numerwbenchmark11'] = [np.nan if numerwbenchmark11 =='*' else float(numerwbenchmark11) for numerwbenchmark11 in sat2019cali['numerwbenchmark11'].values]

# %%
#check again whether * is gone, by checking first row(earlier on row 1 is *)
sat2019cali['numerwbenchmark11'][1]
#yay!
# Out:
# nan

# %%
#now check whether the numerwbenchmark11 is a float type
sat2019cali['numerwbenchmark11']
#yay!
# Out:
# 0          NaN
# 1          NaN
# 2         42.0
# 3         97.0
# 4          NaN
#          ...
# 2575     454.0
# 2576    4583.0
# 2577      94.0
# 2578    1702.0
# 2579       NaN
# Name: numerwbenchmark11, Length: 2580, dtype: float64

# %%
sat2019cali['numtsttakr11']
# Out:
# 0          0.0
# 1          6.0
# 2        174.0
# 3        275.0
# 4          5.0
#          ...
# 2575     474.0
# 2576    5157.0
# 2577     126.0
# 2578    2042.0
# 2579       NaN
# Name: numtsttakr11, Length: 2580, dtype: float64

# %%
#find out the columns with the most NaN Values
#drop all the NaN in the column with the most NaN values

# %%
#what about all these? All got *! 
sat2019cali['numerwbenchmark12']
sat2019cali['pcterwbenchmark12']
sat2019cali['nummathbenchmark12']
sat2019cali['pctmathbenchmark12']
sat2019cali['pctbothbenchmark12']
sat2019cali['totnumbothbenchmark12']


sat2019cali['pcterwbenchmark11']
sat2019cali['nummathbenchmark11']
sat2019cali['pctmathbenchmark11']
sat2019cali['pctbothbenchmark11']
sat2019cali['totnumbothbenchmark11']
# Out:
# 0        NaN
# 1          *
# 2         11
# 3         35
# 4          *
#         ...
# 2575     421
# 2576    3853
# 2577      47
# 2578    1482
# 2579     NaN
# Name: totnumbothbenchmark11, Length: 2580, dtype: object

# %%
sat2019cali['numerwbenchmark12'] = [np.nan if numerwbenchmark12 =='*' else float(numerwbenchmark12) for numerwbenchmark12 in sat2019cali['numerwbenchmark12'].values]
sat2019cali['pcterwbenchmark12'] = [np.nan if pcterwbenchmark12 =='*' else float(pcterwbenchmark12) for pcterwbenchmark12 in sat2019cali['pcterwbenchmark12'].values]
sat2019cali['nummathbenchmark12'] = [np.nan if nummathbenchmark12 =='*' else float(nummathbenchmark12) for nummathbenchmark12 in sat2019cali['nummathbenchmark12'].values]
sat2019cali['pctmathbenchmark12'] = [np.nan if pctmathbenchmark12 =='*' else float(pctmathbenchmark12) for pctmathbenchmark12 in sat2019cali['pctmathbenchmark12'].values]
sat2019cali['pctbothbenchmark12'] = [np.nan if pctbothbenchmark12 =='*' else float(pctbothbenchmark12) for pctbothbenchmark12 in sat2019cali['pctbothbenchmark12'].values]
sat2019cali['totnumbothbenchmark12'] = [np.nan if totnumbothbenchmark12 =='*' else float(totnumbothbenchmark12) for totnumbothbenchmark12 in sat2019cali['totnumbothbenchmark12'].values]

sat2019cali['pcterwbenchmark11'] = [np.nan if pcterwbenchmark11 =='*' else float(pcterwbenchmark11) for pcterwbenchmark11 in sat2019cali['pcterwbenchmark11'].values]
sat2019cali['nummathbenchmark11'] = [np.nan if nummathbenchmark11 =='*' else float(nummathbenchmark11) for nummathbenchmark11 in sat2019cali['nummathbenchmark11'].values]
sat2019cali['pctmathbenchmark11'] = [np.nan if pctmathbenchmark11 =='*' else float(pctmathbenchmark11) for pctmathbenchmark11 in sat2019cali['pctmathbenchmark11'].values]
sat2019cali['pctbothbenchmark11'] = [np.nan if pctbothbenchmark11 =='*' else float(pctbothbenchmark11) for pctbothbenchmark11 in sat2019cali['pctbothbenchmark11'].values]
sat2019cali['totnumbothbenchmark11'] = [np.nan if totnumbothbenchmark11 =='*' else float(totnumbothbenchmark11) for totnumbothbenchmark11 in sat2019cali['totnumbothbenchmark11'].values]

# %%
sat2019cali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cds                    2579 non-null   float64
#  1   ccode                  2579 non-null   float64
#  2   cdcode                 2579 non-null   float64
#  3   scode                  2579 non-null   float64
#  4   rtype                  2579 non-null   object
#  5   sname                  1982 non-null   object
#  6   dname                  2521 non-null   object
#  7   cname                  2579 non-null   object
#  8   enroll12               2579 non-null   float64
#  9   numtsttakr12           2579 non-null   float64
#  10  numerwbenchmark12      1722 non-null   float64
#  11  pcterwbenchmark12      1722 non-null   float64
#  12  nummathbenchmark12     1722 non-null   float64
#  13  pctmathbenchmark12     1722 non-null   float64
# ...

# %%
#remove the unnamed column
sat2019cali.drop(columns=['unnamed: 25'], inplace=True)

# %%
sat2019cali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cds                    2579 non-null   float64
#  1   ccode                  2579 non-null   float64
#  2   cdcode                 2579 non-null   float64
#  3   scode                  2579 non-null   float64
#  4   rtype                  2579 non-null   object
#  5   sname                  1982 non-null   object
#  6   dname                  2521 non-null   object
#  7   cname                  2579 non-null   object
#  8   enroll12               2579 non-null   float64
#  9   numtsttakr12           2579 non-null   float64
#  10  numerwbenchmark12      1722 non-null   float64
#  11  pcterwbenchmark12      1722 non-null   float64
#  12  nummathbenchmark12     1722 non-null   float64
#  13  pctmathbenchmark12     1722 non-null   float64
# ...

# %%
sat2019cali.isnull().sum()
# Out:
# cds                        1
# ccode                      1
# cdcode                     1
# scode                      1
# rtype                      1
# sname                    598
# dname                     59
# cname                      1
# enroll12                   1
# numtsttakr12               1
# numerwbenchmark12        858
# pcterwbenchmark12        858
# nummathbenchmark12       858
# pctmathbenchmark12       858
# enroll11                   1
# numtsttakr11               1
# numerwbenchmark11        844
# pcterwbenchmark11        844
# nummathbenchmark11       844
# pctmathbenchmark11       844
# totnumbothbenchmark12    858
# pctbothbenchmark12       858
# totnumbothbenchmark11    844
# pctbothbenchmark11       844
# year                       1
# dtype: int64

# %%
sat2019cali
# Out:
#                cds  ccode     cdcode      scode rtype  \
# 0     6.615981e+12    6.0   661598.0   630046.0     S
# 1     6.616061e+12    6.0   661606.0   634758.0     S
# 2     1.964733e+13   19.0  1964733.0  1930924.0     S
# 3     1.964733e+13   19.0  1964733.0  1931476.0     S
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# ...            ...    ...        ...        ...   ...
# 2575  5.772678e+13   57.0  5772678.0        0.0     D
# 2576  7.000000e+12    7.0   700000.0        0.0     C
# 2577  1.700000e+13   17.0  1700000.0        0.0     C
# 2578  3.800000e+13   38.0  3800000.0        0.0     C
# 2579           NaN    NaN        NaN        NaN   NaN
#
#                         sname                dname          cname  enroll12  \
# 0     Colusa Alternative Home       Colusa Unified         Colusa      18.0
# 1             Maxwell Sr High      Maxwell Unified         Colusa      29.0
# 2         Belmont Senior High  Los Angeles Unified    Los Angeles     206.0
# ...

# %%
sat2019cali.isnull().sum().plot(kind='barh') #using a barchart to see the number of missing values
plt.title('Count of Missing Values');

# %% [markdown]
# ## Data Import and Cleaning

# %%
def replace_word(x):
    x = x.replace(' County','')
    return x
               
hhincome2019['county'] = hhincome2019['county'].apply(lambda x: replace_word(x))
hhincome2019 = hhincome2019.drop([0])

# %%
hhincome2019 = hhincome2019.rename(columns={'Unnamed: 2': 'marginoferror'})
hhincome2019.reset_index(inplace=True)
hhincome2019
# Out:
#     index           county medianhouseholdincome marginoferror
# 0       1          Alameda               $99,406      +/- $921
# 1       2           Alpine               $63,750   +/- $17,778
# 2       3           Amador               $62,772    +/- $2,756
# 3       4            Butte               $52,537    +/- $1,618
# 4       5        Calaveras               $63,158    +/- $4,128
# 5       6           Colusa               $59,401    +/- $4,265
# 6       7     Contra Costa               $99,716    +/- $1,157
# 7       8        Del Norte               $45,283    +/- $5,017
# 8       9        El Dorado               $83,377    +/- $2,342
# 9      10           Fresno               $53,969      +/- $794
# 10     11            Glenn               $49,633    +/- $2,854
# 11     12         Humboldt               $48,041    +/- $1,798
# 12     13         Imperial               $47,622    +/- $1,761
# 13     14             Inyo               $57,316    +/- $4,087
# ...

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
print(f'sat2019cali_dataframe shape: {sat2019cali.shape}')
print(f'hhincome2019_dataframe shape: {hhincome2019.shape}')
# Out:
# sat2019cali_dataframe shape: (2580, 25)
# hhincome2019_dataframe shape: (58, 4)

# %%
#data dont match, so re-check your sat2019cali DF, look by county!!
sat2019cali = sat2019cali[sat2019cali.rtype=='C']
sat2019cali.shape
# Out:
# (58, 25)

# %%
#now recheck your dataframe shape
print(f'sat2019cali_dataframe shape: {sat2019cali.shape}')
print(f'hhincome2019_dataframe shape: {hhincome2019.shape}')
# Out:
# sat2019cali_dataframe shape: (58, 25)
# hhincome2019_dataframe shape: (58, 4)

# %%
sat2019cali.columns
# Out:
# Index(['cds', 'ccode', 'cdcode', 'scode', 'rtype', 'sname', 'dname', 'cname',
#        'enroll12', 'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
#        'nummathbenchmark12', 'pctmathbenchmark12', 'enroll11', 'numtsttakr11',
#        'numerwbenchmark11', 'pcterwbenchmark11', 'nummathbenchmark11',
#        'pctmathbenchmark11', 'totnumbothbenchmark12', 'pctbothbenchmark12',
#        'totnumbothbenchmark11', 'pctbothbenchmark11', 'year'],
#       dtype='object')

# %%
hhincome2019.columns
# Out:
# Index(['index', 'county', 'medianhouseholdincome', 'marginoferror'], dtype='object')

# %%
#now sort the sat2019cali since hhincome2019 is already sorted. 
sat2019cali = sat2019cali.sort_values(by=['cname'])
sat2019cali
# Out:
#                cds  ccode     cdcode  scode rtype sname dname  \
# 2004  1.000000e+12    1.0   100000.0    0.0     C   NaN   NaN
# 2012  2.000000e+12    2.0   200000.0    0.0     C   NaN   NaN
# 2013  3.000000e+12    3.0   300000.0    0.0     C   NaN   NaN
# 2026  4.000000e+12    4.0   400000.0    0.0     C   NaN   NaN
# 1991  5.000000e+12    5.0   500000.0    0.0     C   NaN   NaN
# 2027  6.000000e+12    6.0   600000.0    0.0     C   NaN   NaN
# 2576  7.000000e+12    7.0   700000.0    0.0     C   NaN   NaN
# 2019  8.000000e+12    8.0   800000.0    0.0     C   NaN   NaN
# 1981  9.000000e+12    9.0   900000.0    0.0     C   NaN   NaN
# 2005  1.000000e+13   10.0  1000000.0    0.0     C   NaN   NaN
# 2001  1.100000e+13   11.0  1100000.0    0.0     C   NaN   NaN
# 2023  1.200000e+13   12.0  1200000.0    0.0     C   NaN   NaN
# 2024  1.300000e+13   13.0  1300000.0    0.0     C   NaN   NaN
# 2028  1.400000e+13   14.0  1400000.0    0.0     C   NaN   NaN
# ...

# %%
hhincome2019 = hhincome2019.rename(columns={'county': 'cname'})
hhincome2019.head()
# Out:
#    index      cname medianhouseholdincome marginoferror
# 0      1    Alameda               $99,406      +/- $921
# 1      2     Alpine               $63,750   +/- $17,778
# 2      3     Amador               $62,772    +/- $2,756
# 3      4      Butte               $52,537    +/- $1,618
# 4      5  Calaveras               $63,158    +/- $4,128

# %%
hhincome2019.info('medianhouseholdincome')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  58 non-null     int64
#  1   cname                  58 non-null     object
#  2   medianhouseholdincome  58 non-null     object
#  3   marginoferror          58 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.9+ KB

# %%
#to remove $ and commas, and change value type to int
hhincome2019['medianhouseholdincome'] = hhincome2019['medianhouseholdincome'].str.replace(',', '').str.replace('$', '').astype(int)

# %%
hhincome2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  58 non-null     int64
#  1   cname                  58 non-null     object
#  2   medianhouseholdincome  58 non-null     int64
#  3   marginoferror          58 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 1.9+ KB

# %%
sat2019cali = sat2019cali.merge(hhincome2019, on = 'cname')

# %%
print(sat2019cali.shape)
sat2019cali
# Out:
# (58, 28)
#              cds  ccode     cdcode  scode rtype sname dname            cname  \
# 0   1.000000e+12    1.0   100000.0    0.0     C   NaN   NaN          Alameda
# 1   2.000000e+12    2.0   200000.0    0.0     C   NaN   NaN           Alpine
# 2   3.000000e+12    3.0   300000.0    0.0     C   NaN   NaN           Amador
# 3   4.000000e+12    4.0   400000.0    0.0     C   NaN   NaN            Butte
# 4   5.000000e+12    5.0   500000.0    0.0     C   NaN   NaN        Calaveras
# 5   6.000000e+12    6.0   600000.0    0.0     C   NaN   NaN           Colusa
# 6   7.000000e+12    7.0   700000.0    0.0     C   NaN   NaN     Contra Costa
# 7   8.000000e+12    8.0   800000.0    0.0     C   NaN   NaN        Del Norte
# 8   9.000000e+12    9.0   900000.0    0.0     C   NaN   NaN        El Dorado
# 9   1.000000e+13   10.0  1000000.0    0.0     C   NaN   NaN           Fresno
# 10  1.100000e+13   11.0  1100000.0    0.0     C   NaN   NaN            Glenn
# ...

# %%
sat2019cali['participation_rate_grade11'] = (sat2019cali['numtsttakr11']/sat2019cali['enroll11'])
sat2019cali['participation_rate_grade12'] = (sat2019cali['numtsttakr12']/sat2019cali['enroll12'])

# %%
sat2019cali
# Out:
#              cds  ccode     cdcode  scode rtype sname dname            cname  \
# 0   1.000000e+12    1.0   100000.0    0.0     C   NaN   NaN          Alameda
# 1   2.000000e+12    2.0   200000.0    0.0     C   NaN   NaN           Alpine
# 2   3.000000e+12    3.0   300000.0    0.0     C   NaN   NaN           Amador
# 3   4.000000e+12    4.0   400000.0    0.0     C   NaN   NaN            Butte
# 4   5.000000e+12    5.0   500000.0    0.0     C   NaN   NaN        Calaveras
# 5   6.000000e+12    6.0   600000.0    0.0     C   NaN   NaN           Colusa
# 6   7.000000e+12    7.0   700000.0    0.0     C   NaN   NaN     Contra Costa
# 7   8.000000e+12    8.0   800000.0    0.0     C   NaN   NaN        Del Norte
# 8   9.000000e+12    9.0   900000.0    0.0     C   NaN   NaN        El Dorado
# 9   1.000000e+13   10.0  1000000.0    0.0     C   NaN   NaN           Fresno
# 10  1.100000e+13   11.0  1100000.0    0.0     C   NaN   NaN            Glenn
# ...

# %%
sat2019cali.drop(columns='index', inplace=True)

# %%
print(sat2019cali.columns)
sat2019cali
# Out:
# Index(['cds', 'ccode', 'cdcode', 'scode', 'rtype', 'sname', 'dname', 'cname',
#        'enroll12', 'numtsttakr12', 'numerwbenchmark12', 'pcterwbenchmark12',
#        'nummathbenchmark12', 'pctmathbenchmark12', 'enroll11', 'numtsttakr11',
#        'numerwbenchmark11', 'pcterwbenchmark11', 'nummathbenchmark11',
#        'pctmathbenchmark11', 'totnumbothbenchmark12', 'pctbothbenchmark12',
#        'totnumbothbenchmark11', 'pctbothbenchmark11', 'year',
#        'medianhouseholdincome', 'marginoferror', 'participation_rate_grade11',
#        'participation_rate_grade12'],
#       dtype='object')
#              cds  ccode     cdcode  scode rtype sname dname            cname  \
# 0   1.000000e+12    1.0   100000.0    0.0     C   NaN   NaN          Alameda
# 1   2.000000e+12    2.0   200000.0    0.0     C   NaN   NaN           Alpine
# 2   3.000000e+12    3.0   300000.0    0.0     C   NaN   NaN           Amador
# 3   4.000000e+12    4.0   400000.0    0.0     C   NaN   NaN            Butte
# ...

# %%
print('The median values for participation rates in California are as follows: ')
print('\nMedian value of Participation Rate amongst Grade 11 in California:')
print(sat2019cali['participation_rate_grade11'].median())
print('\nMedian value of Participation Rate amongst Grade 12 in California:')
print(sat2019cali['participation_rate_grade12'].median())
# Out:
# The median values for participation rates in California are as follows:
#
# Median value of Participation Rate amongst Grade 11 in California:
# 0.2758495145631068
#
# Median value of Participation Rate amongst Grade 12 in California:
# 0.24126637554585154

# %%
sat2019cali.sort_values(by=['participation_rate_grade11'],ascending=False).tail()
# Out:
#              cds  ccode     cdcode  scode rtype sname dname     cname  \
# 2   3.000000e+12    3.0   300000.0    0.0     C   NaN   NaN    Amador
# 54  5.500000e+13   55.0  5500000.0    0.0     C   NaN   NaN  Tuolumne
# 51  5.200000e+13   52.0  5200000.0    0.0     C   NaN   NaN    Tehama
# 13  1.400000e+13   14.0  1400000.0    0.0     C   NaN   NaN      Inyo
# 1   2.000000e+12    2.0   200000.0    0.0     C   NaN   NaN    Alpine
#
#     enroll12  numtsttakr12  ...  pctmathbenchmark11  totnumbothbenchmark12  \
# 2      305.0          53.0  ...               85.42                   33.0
# 54     518.0          80.0  ...               64.71                   48.0
# 51     688.0          91.0  ...               75.29                   52.0
# 13     548.0          88.0  ...               46.91                   28.0
# 1        0.0           0.0  ...                 NaN                    NaN
#
#     pctbothbenchmark12  totnumbothbenchmark11  pctbothbenchmark11     year  \
# ...

# %%
sat2019cali.sort_values('participation_rate_grade11')[['cname','participation_rate_grade11']].head(4)
# Out:
#        cname  participation_rate_grade11
# 13      Inyo                    0.091941
# 51    Tehama                    0.109677
# 54  Tuolumne                    0.137931
# 2     Amador                    0.139535

# %%
print('The 3 counties with the lowest participation rates in SAT amongst grade 11 is:')
print('\nInyo with 9.194098%')
print('Tehama with 10.967742%')
print('Tuolumne with 13.793103%')
# Out:
# The 3 counties with the lowest participation rates in SAT amongst grade 11 is:
#
# Inyo with 9.194098%
# Tehama with 10.967742%
# Tuolumne with 13.793103%

# %%
sat2019cali.sort_values(by=['participation_rate_grade11'],ascending=False).head()
# Out:
#              cds  ccode     cdcode  scode rtype sname dname           cname  \
# 42  4.300000e+13   43.0  4300000.0    0.0     C   NaN   NaN     Santa Clara
# 18  1.900000e+13   19.0  1900000.0    0.0     C   NaN   NaN     Los Angeles
# 19  2.000000e+13   20.0  2000000.0    0.0     C   NaN   NaN          Madera
# 35  3.600000e+13   36.0  3600000.0    0.0     C   NaN   NaN  San Bernardino
# 55  5.600000e+13   56.0  5600000.0    0.0     C   NaN   NaN         Ventura
#
#     enroll12  numtsttakr12  ...  pctmathbenchmark11  totnumbothbenchmark12  \
# 42   21656.0        6920.0  ...               65.14                 4620.0
# 18  114618.0       48676.0  ...               38.18                18555.0
# 19    2352.0         442.0  ...               24.50                  127.0
# 35   31635.0       10544.0  ...               36.96                 4083.0
# 55   10750.0        4534.0  ...               49.32                 1967.0
#
# ...

# %%
sat2019cali.sort_values('participation_rate_grade11')[['cname','participation_rate_grade11']].tail()
# Out:
#              cname  participation_rate_grade11
# 35  San Bernardino                    0.518696
# 19          Madera                    0.556514
# 18     Los Angeles                    0.610176
# 42     Santa Clara                    0.670016
# 1           Alpine                         NaN

# %%
print('The 3 counties with the highest participation rates in SAT amongst grade 11 is:')
print('\nSanta Clara with 67.001610%')
print('Los Angeles with 61.017570%')
print('Madera with 55.651424%')
# Out:
# The 3 counties with the highest participation rates in SAT amongst grade 11 is:
#
# Santa Clara with 67.001610%
# Los Angeles with 61.017570%
# Madera with 55.651424%

# %%
sat2019cali.sort_values(by=['participation_rate_grade12'],ascending=False).tail()
# Out:
#              cds  ccode     cdcode  scode rtype sname dname    cname  \
# 51  5.200000e+13   52.0  5200000.0    0.0     C   NaN   NaN   Tehama
# 28  2.900000e+13   29.0  2900000.0    0.0     C   NaN   NaN   Nevada
# 25  2.600000e+13   26.0  2600000.0    0.0     C   NaN   NaN     Mono
# 52  5.300000e+13   53.0  5300000.0    0.0     C   NaN   NaN  Trinity
# 1   2.000000e+12    2.0   200000.0    0.0     C   NaN   NaN   Alpine
#
#     enroll12  numtsttakr12  ...  pctmathbenchmark11  totnumbothbenchmark12  \
# 51     688.0          91.0  ...               75.29                   52.0
# 28    1869.0         186.0  ...               88.24                  127.0
# 25     420.0          37.0  ...               74.19                   21.0
# 52     154.0          13.0  ...               70.59                    NaN
# 1        0.0           0.0  ...                 NaN                    NaN
#
#     pctbothbenchmark12  totnumbothbenchmark11  pctbothbenchmark11     year  \
# ...

# %%
sat2019cali.sort_values('participation_rate_grade12')[['cname','participation_rate_grade12']].head()
# Out:
#        cname  participation_rate_grade12
# 52   Trinity                    0.084416
# 25      Mono                    0.088095
# 28    Nevada                    0.099518
# 51    Tehama                    0.132267
# 54  Tuolumne                    0.154440

# %%
print('The 3 counties with the lowest participation rates in SAT amongst grade 12 is:')
print('\nTrinity with 8.441558%')
print('Mono with 8.809524%')
print('Nevada with 9.951846%')
# Out:
# The 3 counties with the lowest participation rates in SAT amongst grade 12 is:
#
# Trinity with 8.441558%
# Mono with 8.809524%
# Nevada with 9.951846%

# %%
sat2019cali.sort_values(by=['participation_rate_grade12'],ascending=False).head()
# Out:
#              cds  ccode     cdcode  scode rtype sname dname          cname  \
# 37  3.800000e+13   38.0  3800000.0    0.0     C   NaN   NaN  San Francisco
# 40  4.100000e+13   41.0  4100000.0    0.0     C   NaN   NaN      San Mateo
# 18  1.900000e+13   19.0  1900000.0    0.0     C   NaN   NaN    Los Angeles
# 55  5.600000e+13   56.0  5600000.0    0.0     C   NaN   NaN        Ventura
# 32  3.300000e+13   33.0  3300000.0    0.0     C   NaN   NaN      Riverside
#
#     enroll12  numtsttakr12  ...  pctmathbenchmark11  totnumbothbenchmark12  \
# 37    4447.0        2256.0  ...               76.69                 1248.0
# 40    7235.0        3113.0  ...               79.55                 1857.0
# 18  114618.0       48676.0  ...               38.18                18555.0
# 55   10750.0        4534.0  ...               49.32                 1967.0
# 32   34277.0       14070.0  ...               43.61                 4799.0
#
# ...

# %%
sat2019cali.sort_values('participation_rate_grade12')[['cname','participation_rate_grade12']].tail()
# Out:
#             cname  participation_rate_grade12
# 55        Ventura                    0.421767
# 18    Los Angeles                    0.424680
# 40      San Mateo                    0.430270
# 37  San Francisco                    0.507308
# 1          Alpine                         NaN

# %%
print('The 3 counties with the highest participation rates in SAT amongst grade 12 is:')
print('\nSan Francisco with 50.730830%')
print('San Mateo with 43.026962%')
print('Los Angeles with 42.468024%')
# Out:
# The 3 counties with the highest participation rates in SAT amongst grade 12 is:
#
# San Francisco with 50.730830%
# San Mateo with 43.026962%
# Los Angeles with 42.468024%

# %% [markdown]
# #BONUS: CREATE A FUNCTION TO PRINT LOWEST 3 AND TOP 3 PARTICIPATION RATES IN GRADE 11 AND GRADE 12 RESPECTIVELY ALONG WITH COUNTY
# #def lowestparticipation(column):
#
# #lis = []
# #for col, key in sat2019cali.items():
# #lis.extend(key) while key in sat2019cali[col] <= sat2019cali['column'].tail(4)

# %%
pd.options.display.float_format = '{:.2f}'.format
sat2019cali.describe().T
# Out:
#                             count              mean               std  \
# cds                         58.00 29500000000000.00 16886878535320.45
# ccode                       58.00             29.50             16.89
# cdcode                      58.00        2950000.00        1688687.85
# scode                       58.00              0.00              0.00
# enroll12                    58.00           8442.24          17344.16
# numtsttakr12                58.00           2938.12           7079.37
# numerwbenchmark12           55.00           2117.93           4612.16
# pcterwbenchmark12           55.00             74.40              9.79
# nummathbenchmark12          55.00           1482.55           3131.26
# pctmathbenchmark12          55.00             52.19             13.10
# enroll11                    58.00           8186.95          16833.62
# numtsttakr11                58.00           3562.79           9588.04
# ...

# %%
sat2019cali
# Out:
#                  cds  ccode     cdcode  scode rtype sname dname  \
# 0   1000000000000.00   1.00  100000.00   0.00     C   NaN   NaN
# 1   2000000000000.00   2.00  200000.00   0.00     C   NaN   NaN
# 2   3000000000000.00   3.00  300000.00   0.00     C   NaN   NaN
# 3   4000000000000.00   4.00  400000.00   0.00     C   NaN   NaN
# 4   5000000000000.00   5.00  500000.00   0.00     C   NaN   NaN
# 5   6000000000000.00   6.00  600000.00   0.00     C   NaN   NaN
# 6   7000000000000.00   7.00  700000.00   0.00     C   NaN   NaN
# 7   8000000000000.00   8.00  800000.00   0.00     C   NaN   NaN
# 8   9000000000000.00   9.00  900000.00   0.00     C   NaN   NaN
# 9  10000000000000.00  10.00 1000000.00   0.00     C   NaN   NaN
# 10 11000000000000.00  11.00 1100000.00   0.00     C   NaN   NaN
# 11 12000000000000.00  12.00 1200000.00   0.00     C   NaN   NaN
# 12 13000000000000.00  13.00 1300000.00   0.00     C   NaN   NaN
# 13 14000000000000.00  14.00 1400000.00   0.00     C   NaN   NaN
# ...

# %%
sat2019cali['medianhouseholdincome'].describe()
# Out:
# count       58.00
# mean     67713.60
# std      20213.45
# min      40846.00
# 25%      53430.50
# 50%      62516.00
# 75%      80508.50
# max     124055.00
# Name: medianhouseholdincome, dtype: float64

# %%
sat2019cali['medianhouseholdincome'].tail()
# Out:
# 53    49687
# 54    60108
# 55    88131
# 56    70228
# 57    58054
# Name: medianhouseholdincome, dtype: int64

# %%
ax = sns.displot(sat2019cali['medianhouseholdincome'], bins=50, kde=False) # seaborn dis plot, defaults to histogram

# %%
sat2019cali.drop(columns=['cds', 'cdcode', 'scode','dname',  'sname'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-bf527c547f65> in <module>
# ----> 1 sat2019cali.drop(columns=['cds', 'cdcode', 'scode','dname',  'sname'], inplace=True)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
sat2019cali
# Out:
#     ccode rtype            cname  enroll12  numtsttakr12  numerwbenchmark12  \
# 0    1.00     C          Alameda  17567.00       5946.00            4566.00
# 1    2.00     C           Alpine      0.00          0.00                NaN
# 2    3.00     C           Amador    305.00         53.00              44.00
# 3    4.00     C            Butte   2551.00        551.00             453.00
# 4    5.00     C        Calaveras    451.00         90.00              81.00
# 5    6.00     C           Colusa    339.00         74.00              39.00
# 6    7.00     C     Contra Costa  14593.00       5412.00            3798.00
# 7    8.00     C        Del Norte    363.00         72.00              50.00
# 8    9.00     C        El Dorado   2226.00        604.00             547.00
# 9   10.00     C           Fresno  14299.00       4070.00            2664.00
# 10  11.00     C            Glenn    500.00         90.00              58.00
# ...

# %%
sns.boxplot(x=sat2019cali['medianhouseholdincome'],  width=0.6);

# %%
print('Median household income and participation rates amongst grade 12 is positively correlated, with a number of 0.69')
print('\nSimilarly, median household income and participation rates amongst grade 11 is positively correlated as well, with a number of 0.56')
fig = plt.figure(figsize=(24,18))
sns.color_palette("rainbow")
ax = sns.heatmap(sat2019cali.corr(), square = True, annot=True, cmap = "rainbow", center=0)
ax.set_title('Correlation Heatmap for SAT participation in 2019 in California Data\n');
# Out:
# Median household income and participation rates amongst grade 12 is positively correlated, with a number of 0.69
#
# Similarly, median household income and participation rates amongst grade 11 is positively correlated as well, with a number of 0.56

# %% [markdown]
# things noticed:
# - Median household income is positively correlated with participation rates in grade 11 and 12
# - median household income is somewhat correlated with percentage of SAT scores bench mark 11 and 12.

# %%
plt.figure(figsize=(10,7))
sns.regplot(x='medianhouseholdincome', y='participation_rate_grade11', data = sat2019cali,
           scatter_kws={'s':15, 'color':'limegreen'}, line_kws={'color': 'purple'});

# %%
plt.figure(figsize=(10,7))
sns.regplot(x='medianhouseholdincome', y='participation_rate_grade12', data = sat2019cali,
           scatter_kws={'s':15, 'color':'skyblue'}, line_kws={'color': 'red'});

# %%
#percentage of totalERW
#plot best fit line in poverty 5 from poor andrich

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Show table for participation rates by 11 
# show table for participation rates by 11 
# show table of income 
#do head map and focus on significant 
#lm plot under seaborn

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
